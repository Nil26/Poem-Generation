# %% [markdown]
# ## Model

# %%
import torch.nn as nn

# %%
class LSTMModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, ntoken, ninp, nhid, nlayers, dropout=0.5):
        super(LSTMModel, self).__init__()
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.rnn = nn.LSTM(ninp, nhid, nlayers, dropout=dropout)
        self.decoder = nn.Linear(nhid, ntoken)

        self.init_weights()

        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                weight.new_zeros(self.nlayers, bsz, self.nhid))

# %% [markdown]
# ## Data preprocessing

# %%
import os
from io import open
import torch
from nltk.tokenize import wordpunct_tokenize
import json
import enchant
d_english = enchant.Dict("en_US")
valid_noword = ['end_of_poem','!','"',',','.',':',';','?']

class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path):
        self.dictionary = Dictionary()
        self.train = self.tokenize(os.path.join(path, 'poems.json'))

    def tokenize(self, path):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding="utf8") as f:
            tokens = 0
            for poem in f:
                poem_json = json.loads(poem)
                lines = poem_json['text'].split('\n') + ['end_of_poem']
                for words in lines:
                    for word in wordpunct_tokenize(words):
                        if d_english.check(word) or word in valid_noword:
                            self.dictionary.add_word(word.lower())
                            tokens += 1

        # Tokenize file content
        with open(path, 'r', encoding="utf8") as f:
            ids = torch.LongTensor(tokens)
            token = 0
            for poem in f:
                poem_json = json.loads(poem)
                lines = poem_json['text'].split('\n') + ['end_of_poem']
                for words in lines:
                    for word in wordpunct_tokenize(words):
                        if d_english.check(word) or word in valid_noword:
                            ids[token] = self.dictionary.word2idx[word.lower()]
                            token += 1

        return ids

# %% [markdown]
# ## Build and train

# %%
import time
import math
import os
import torch
import torch.nn as nn

# %% [markdown]
# Set the hyperparameters

# %%
# parameters
seed = 1111
data = './'
batch_size = 32
emsize = 200
nhid = 500
nlayers = 2
dropout = 0.5
bptt = 6
log_interval = 100
learning_rate_init = 0.2
epochs = 40
save = 'model.pt'

# Set the random seed manually for reproducibility.
torch.manual_seed(seed)

device = torch.device("cpu")

# %%
###############################################################################
# Load data
###############################################################################

corpus = Corpus(data)

# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

train_data = batchify(corpus.train, batch_size)

###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
model = LSTMModel(ntokens, emsize, nhid, nlayers, dropout).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate_init)
# scheduler for modifying the lr
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=0.9)

###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

def train():
    # Turn on training mode which enables dropout.
    model.train()
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        hidden = repackage_hidden(hidden)
        optimizer.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()                
        optimizer.step()
        # output to screen
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | ms/batch {:5.2f} | '
                    'loss {:5.2f} '.format(
                epoch, batch, len(train_data) // bptt,
                elapsed * 1000 / log_interval, loss.item()))
            start_time = time.time()

# %%
# Loop over epochs.
best_val_loss = None

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        scheduler.step()
        train()
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s '.format(epoch, (time.time() - epoch_start_time)))
        print('-' * 89)
        # Save the model
        with open(save, 'wb') as f:
            torch.save(model, f)
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# | epoch   1 |   100/ 4431 batches | ms/batch 231.63 | loss  8.22
# | epoch   1 |   200/ 4431 batches | ms/batch 223.57 | loss  7.08
# | epoch   1 |   300/ 4431 batches | ms/batch 222.60 | loss  7.13
# | epoch   1 |   400/ 4431 batches | ms/batch 223.42 | loss  7.25
# | epoch   1 |   500/ 4431 batches | ms/batch 219.66 | loss  7.66
# | epoch   1 |   600/ 4431 batches | ms/batch 220.15 | loss  7.04
# | epoch   1 |   700/ 4431 batches | ms/batch 227.41 | loss  7.05
# | epoch   1 |   800/ 4431 batches | ms/batch 221.63 | loss  6.93
# | epoch   1 |   900/ 4431 batches | ms/batch 224.77 | loss  7.06
# | epoch   1 |  1000/ 4431 batches | ms/batch 224.83 | loss  6.94
# | epoch   1 |  1100/ 4431 batches | ms/batch 223.99 | loss  6.84
# | epoch   1 |  1200/ 4431 batches | ms/batch 223.86 | loss  6.87
# | epoch   1 |  1300/ 4431 batches | ms/batch 226.36 | loss  6.88
# | epoch   1 |  1400/ 4431 batches | ms/batch 223.78 | loss  7.13
# | epoch   1 |  1500/ 4431 batches | ms/batch 225.90 | loss  6.99
# | epoch   1 |  1600/ 4431 batches | ms/batch 224.68 | loss  6.65
# | epoch   1 |  1700/ 4431 batches | ms/batch 225.70 | loss  7.32
# | epoch   1 |  1800/ 4431 batches | ms/batch 225.77 | loss  6.59
# | epoch   1 |  1900/ 4431 batches | ms/batch 222.01 | loss  7.30
# | epoch   1 |  2000/ 4431 batches | ms/batch 220.47 | loss  6.78
# | epoch   1 |  2100/ 4431 batches | ms/batch 225.33 | loss  6.82
# | epoch   1 |  2200/ 4431 batches | ms/batch 222.83 | loss  7.02
# | epoch   1 |  2300/ 4431 batches | ms/batch 222.98 | loss  6.85
# | epoch   1 |  2400/ 4431 batches | ms/batch 226.07 | loss  7.07
# | epoch   1 |  2500/ 4431 batches | ms/batch 225.03 | loss  7.00
# | epoch   1 |  2600/ 4431 batches | ms/batch 223.09 | loss  6.41
# | epoch   1 |  2700/ 4431 batches | ms/batch 224.58 | loss  6.65
# | epoch   1 |  2800/ 4431 batches | ms/batch 225.81 | loss  6.85
# | epoch   1 |  2900/ 4431 batches | ms/batch 224.03 | loss  6.65
# | epoch   1 |  3000/ 4431 batches | ms/batch 222.61 | loss  6.88
# | epoch   1 |  3100/ 4431 batches | ms/batch 221.82 | loss  6.93
# | epoch   1 |  3200/ 4431 batches | ms/batch 223.20 | loss  6.85
# | epoch   1 |  3300/ 4431 batches | ms/batch 233.42 | loss  7.12
# | epoch   1 |  3400/ 4431 batches | ms/batch 227.56 | loss  7.13
# | epoch   1 |  3500/ 4431 batches | ms/batch 224.93 | loss  6.74
# | epoch   1 |  3600/ 4431 batches | ms/batch 223.38 | loss  6.94
# | epoch   1 |  3700/ 4431 batches | ms/batch 225.95 | loss  6.66
# | epoch   1 |  3800/ 4431 batches | ms/batch 225.45 | loss  6.79
# | epoch   1 |  3900/ 4431 batches | ms/batch 223.43 | loss  7.05
# | epoch   1 |  4000/ 4431 batches | ms/batch 221.87 | loss  7.04
# | epoch   1 |  4100/ 4431 batches | ms/batch 223.63 | loss  6.97
# | epoch   1 |  4200/ 4431 batches | ms/batch 221.77 | loss  7.04
# | epoch   1 |  4300/ 4431 batches | ms/batch 222.20 | loss  7.07
# | epoch   1 |  4400/ 4431 batches | ms/batch 224.29 | loss  6.58
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 993.39s
# -----------------------------------------------------------------------------------------
# /u/home/zhshang/anaconda3/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type LSTMModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# | epoch   2 |   100/ 4431 batches | ms/batch 226.78 | loss  6.84
# | epoch   2 |   200/ 4431 batches | ms/batch 226.53 | loss  6.50
# | epoch   2 |   300/ 4431 batches | ms/batch 222.23 | loss  6.73
# | epoch   2 |   400/ 4431 batches | ms/batch 219.21 | loss  6.98
# | epoch   2 |   500/ 4431 batches | ms/batch 225.25 | loss  7.22
# | epoch   2 |   600/ 4431 batches | ms/batch 223.48 | loss  6.79
# | epoch   2 |   700/ 4431 batches | ms/batch 224.20 | loss  6.83
# | epoch   2 |   800/ 4431 batches | ms/batch 220.05 | loss  6.76
# | epoch   2 |   900/ 4431 batches | ms/batch 226.92 | loss  6.93
# | epoch   2 |  1000/ 4431 batches | ms/batch 232.05 | loss  6.78
# | epoch   2 |  1100/ 4431 batches | ms/batch 230.05 | loss  6.68
# | epoch   2 |  1200/ 4431 batches | ms/batch 222.52 | loss  6.70
# | epoch   2 |  1300/ 4431 batches | ms/batch 221.71 | loss  6.71
# | epoch   2 |  1400/ 4431 batches | ms/batch 222.61 | loss  7.01
# | epoch   2 |  1500/ 4431 batches | ms/batch 224.45 | loss  6.81
# | epoch   2 |  1600/ 4431 batches | ms/batch 221.95 | loss  6.54
# | epoch   2 |  1700/ 4431 batches | ms/batch 223.13 | loss  7.17
# | epoch   2 |  1800/ 4431 batches | ms/batch 218.08 | loss  6.50
# | epoch   2 |  1900/ 4431 batches | ms/batch 224.01 | loss  7.18
# | epoch   2 |  2000/ 4431 batches | ms/batch 223.35 | loss  6.61
# | epoch   2 |  2100/ 4431 batches | ms/batch 222.18 | loss  6.76
# | epoch   2 |  2200/ 4431 batches | ms/batch 225.30 | loss  6.96
# | epoch   2 |  2300/ 4431 batches | ms/batch 225.45 | loss  6.79
# | epoch   2 |  2400/ 4431 batches | ms/batch 220.61 | loss  6.93
# | epoch   2 |  2500/ 4431 batches | ms/batch 222.56 | loss  6.84
# | epoch   2 |  2600/ 4431 batches | ms/batch 222.22 | loss  6.30
# | epoch   2 |  2700/ 4431 batches | ms/batch 223.83 | loss  6.58
# | epoch   2 |  2800/ 4431 batches | ms/batch 222.72 | loss  6.77
# | epoch   2 |  2900/ 4431 batches | ms/batch 222.00 | loss  6.59
# | epoch   2 |  3000/ 4431 batches | ms/batch 217.45 | loss  6.83
# | epoch   2 |  3100/ 4431 batches | ms/batch 221.45 | loss  6.83
# | epoch   2 |  3200/ 4431 batches | ms/batch 223.61 | loss  6.73
# | epoch   2 |  3300/ 4431 batches | ms/batch 223.38 | loss  7.09
# | epoch   2 |  3400/ 4431 batches | ms/batch 223.64 | loss  7.05
# | epoch   2 |  3500/ 4431 batches | ms/batch 222.09 | loss  6.71
# | epoch   2 |  3600/ 4431 batches | ms/batch 223.74 | loss  6.86
# | epoch   2 |  3700/ 4431 batches | ms/batch 224.55 | loss  6.68
# | epoch   2 |  3800/ 4431 batches | ms/batch 223.55 | loss  6.82
# | epoch   2 |  3900/ 4431 batches | ms/batch 221.24 | loss  7.06
# | epoch   2 |  4000/ 4431 batches | ms/batch 229.11 | loss  6.96
# | epoch   2 |  4100/ 4431 batches | ms/batch 220.38 | loss  6.90
# | epoch   2 |  4200/ 4431 batches | ms/batch 222.51 | loss  7.02
# | epoch   2 |  4300/ 4431 batches | ms/batch 221.44 | loss  6.99
# | epoch   2 |  4400/ 4431 batches | ms/batch 223.10 | loss  6.49
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 989.62s
# -----------------------------------------------------------------------------------------
# | epoch   3 |   100/ 4431 batches | ms/batch 228.06 | loss  6.85
# | epoch   3 |   200/ 4431 batches | ms/batch 225.34 | loss  6.47
# | epoch   3 |   300/ 4431 batches | ms/batch 227.62 | loss  6.67
# | epoch   3 |   400/ 4431 batches | ms/batch 222.66 | loss  6.92
# | epoch   3 |   500/ 4431 batches | ms/batch 222.11 | loss  7.19
# | epoch   3 |   600/ 4431 batches | ms/batch 221.78 | loss  6.68
# | epoch   3 |   700/ 4431 batches | ms/batch 220.40 | loss  6.75
# | epoch   3 |   800/ 4431 batches | ms/batch 218.91 | loss  6.66
# | epoch   3 |   900/ 4431 batches | ms/batch 223.79 | loss  6.86
# | epoch   3 |  1000/ 4431 batches | ms/batch 224.84 | loss  6.70
# | epoch   3 |  1100/ 4431 batches | ms/batch 220.14 | loss  6.64
# | epoch   3 |  1200/ 4431 batches | ms/batch 220.27 | loss  6.64
# | epoch   3 |  1300/ 4431 batches | ms/batch 226.52 | loss  6.67
# | epoch   3 |  1400/ 4431 batches | ms/batch 223.98 | loss  6.95
# | epoch   3 |  1500/ 4431 batches | ms/batch 222.87 | loss  6.78
# | epoch   3 |  1600/ 4431 batches | ms/batch 221.14 | loss  6.50
# | epoch   3 |  1700/ 4431 batches | ms/batch 224.44 | loss  7.14
# | epoch   3 |  1800/ 4431 batches | ms/batch 222.96 | loss  6.48
# | epoch   3 |  1900/ 4431 batches | ms/batch 224.97 | loss  7.10
# | epoch   3 |  2000/ 4431 batches | ms/batch 222.42 | loss  6.59
# | epoch   3 |  2100/ 4431 batches | ms/batch 224.38 | loss  6.64
# | epoch   3 |  2200/ 4431 batches | ms/batch 223.89 | loss  6.95
# | epoch   3 |  2300/ 4431 batches | ms/batch 225.57 | loss  6.70
# | epoch   3 |  2400/ 4431 batches | ms/batch 221.21 | loss  6.94
# | epoch   3 |  2500/ 4431 batches | ms/batch 221.11 | loss  6.87
# | epoch   3 |  2600/ 4431 batches | ms/batch 225.62 | loss  6.26
# | epoch   3 |  2700/ 4431 batches | ms/batch 225.43 | loss  6.54
# | epoch   3 |  2800/ 4431 batches | ms/batch 228.62 | loss  6.65
# | epoch   3 |  2900/ 4431 batches | ms/batch 236.69 | loss  6.51
# | epoch   3 |  3000/ 4431 batches | ms/batch 224.79 | loss  6.78
# | epoch   3 |  3100/ 4431 batches | ms/batch 222.69 | loss  6.78
# | epoch   3 |  3200/ 4431 batches | ms/batch 221.82 | loss  6.65
# | epoch   3 |  3300/ 4431 batches | ms/batch 221.96 | loss  7.03
# | epoch   3 |  3400/ 4431 batches | ms/batch 224.01 | loss  7.03
# | epoch   3 |  3500/ 4431 batches | ms/batch 227.43 | loss  6.59
# | epoch   3 |  3600/ 4431 batches | ms/batch 225.18 | loss  6.86
# | epoch   3 |  3700/ 4431 batches | ms/batch 219.36 | loss  6.59
# | epoch   3 |  3800/ 4431 batches | ms/batch 222.36 | loss  6.69
# | epoch   3 |  3900/ 4431 batches | ms/batch 221.41 | loss  6.96
# | epoch   3 |  4000/ 4431 batches | ms/batch 223.32 | loss  6.91
# | epoch   3 |  4100/ 4431 batches | ms/batch 219.01 | loss  6.80
# | epoch   3 |  4200/ 4431 batches | ms/batch 223.96 | loss  6.95
# | epoch   3 |  4300/ 4431 batches | ms/batch 218.52 | loss  6.91
# | epoch   3 |  4400/ 4431 batches | ms/batch 223.39 | loss  6.38
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 990.58s
# -----------------------------------------------------------------------------------------
# | epoch   4 |   100/ 4431 batches | ms/batch 223.49 | loss  6.76
# | epoch   4 |   200/ 4431 batches | ms/batch 218.13 | loss  6.34
# | epoch   4 |   300/ 4431 batches | ms/batch 220.66 | loss  6.69
# | epoch   4 |   400/ 4431 batches | ms/batch 225.81 | loss  6.82
# | epoch   4 |   500/ 4431 batches | ms/batch 224.03 | loss  7.09
# | epoch   4 |   600/ 4431 batches | ms/batch 224.07 | loss  6.65
# | epoch   4 |   700/ 4431 batches | ms/batch 226.31 | loss  6.63
# | epoch   4 |   800/ 4431 batches | ms/batch 225.72 | loss  6.61
# | epoch   4 |   900/ 4431 batches | ms/batch 221.99 | loss  6.77
# | epoch   4 |  1000/ 4431 batches | ms/batch 223.81 | loss  6.62
# | epoch   4 |  1100/ 4431 batches | ms/batch 223.53 | loss  6.52
# | epoch   4 |  1200/ 4431 batches | ms/batch 217.97 | loss  6.50
# | epoch   4 |  1300/ 4431 batches | ms/batch 225.04 | loss  6.47
# | epoch   4 |  1400/ 4431 batches | ms/batch 223.17 | loss  6.91
# | epoch   4 |  1500/ 4431 batches | ms/batch 222.06 | loss  6.63
# | epoch   4 |  1600/ 4431 batches | ms/batch 226.61 | loss  6.33
# | epoch   4 |  1700/ 4431 batches | ms/batch 222.29 | loss  7.11
# | epoch   4 |  1800/ 4431 batches | ms/batch 227.70 | loss  6.32
# | epoch   4 |  1900/ 4431 batches | ms/batch 226.51 | loss  6.99
# | epoch   4 |  2000/ 4431 batches | ms/batch 221.38 | loss  6.48
# | epoch   4 |  2100/ 4431 batches | ms/batch 220.61 | loss  6.56
# | epoch   4 |  2200/ 4431 batches | ms/batch 227.03 | loss  6.89
# | epoch   4 |  2300/ 4431 batches | ms/batch 226.26 | loss  6.60
# | epoch   4 |  2400/ 4431 batches | ms/batch 221.44 | loss  6.81
# | epoch   4 |  2500/ 4431 batches | ms/batch 222.81 | loss  6.69
# | epoch   4 |  2600/ 4431 batches | ms/batch 225.28 | loss  6.09
# | epoch   4 |  2700/ 4431 batches | ms/batch 219.53 | loss  6.44
# | epoch   4 |  2800/ 4431 batches | ms/batch 224.99 | loss  6.55
# | epoch   4 |  2900/ 4431 batches | ms/batch 224.04 | loss  6.34
# | epoch   4 |  3000/ 4431 batches | ms/batch 227.82 | loss  6.63
# | epoch   4 |  3100/ 4431 batches | ms/batch 224.14 | loss  6.75
# | epoch   4 |  3200/ 4431 batches | ms/batch 222.09 | loss  6.50
# | epoch   4 |  3300/ 4431 batches | ms/batch 223.20 | loss  6.98
# | epoch   4 |  3400/ 4431 batches | ms/batch 226.37 | loss  6.95
# | epoch   4 |  3500/ 4431 batches | ms/batch 224.13 | loss  6.52
# | epoch   4 |  3600/ 4431 batches | ms/batch 224.00 | loss  6.67
# | epoch   4 |  3700/ 4431 batches | ms/batch 226.01 | loss  6.42
# | epoch   4 |  3800/ 4431 batches | ms/batch 222.74 | loss  6.53
# | epoch   4 |  3900/ 4431 batches | ms/batch 225.33 | loss  6.95
# | epoch   4 |  4000/ 4431 batches | ms/batch 225.36 | loss  6.78
# | epoch   4 |  4100/ 4431 batches | ms/batch 226.84 | loss  6.65
# | epoch   4 |  4200/ 4431 batches | ms/batch 227.49 | loss  6.84
# | epoch   4 |  4300/ 4431 batches | ms/batch 226.64 | loss  6.75
# | epoch   4 |  4400/ 4431 batches | ms/batch 226.38 | loss  6.29
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 993.08s
# -----------------------------------------------------------------------------------------
# | epoch   5 |   100/ 4431 batches | ms/batch 220.98 | loss  6.70
# | epoch   5 |   200/ 4431 batches | ms/batch 221.46 | loss  6.25
# | epoch   5 |   300/ 4431 batches | ms/batch 227.74 | loss  6.55
# | epoch   5 |   400/ 4431 batches | ms/batch 221.26 | loss  6.74
# | epoch   5 |   500/ 4431 batches | ms/batch 220.66 | loss  7.04
# | epoch   5 |   600/ 4431 batches | ms/batch 223.04 | loss  6.57
# | epoch   5 |   700/ 4431 batches | ms/batch 223.39 | loss  6.51
# | epoch   5 |   800/ 4431 batches | ms/batch 223.93 | loss  6.43
# | epoch   5 |   900/ 4431 batches | ms/batch 225.05 | loss  6.66
# | epoch   5 |  1000/ 4431 batches | ms/batch 220.87 | loss  6.53
# | epoch   5 |  1100/ 4431 batches | ms/batch 229.67 | loss  6.38
# | epoch   5 |  1200/ 4431 batches | ms/batch 224.09 | loss  6.42
# | epoch   5 |  1300/ 4431 batches | ms/batch 223.66 | loss  6.36
# | epoch   5 |  1400/ 4431 batches | ms/batch 224.19 | loss  6.81
# | epoch   5 |  1500/ 4431 batches | ms/batch 220.31 | loss  6.55
# | epoch   5 |  1600/ 4431 batches | ms/batch 225.34 | loss  6.26
# | epoch   5 |  1700/ 4431 batches | ms/batch 225.84 | loss  6.99
# | epoch   5 |  1800/ 4431 batches | ms/batch 224.21 | loss  6.24
# | epoch   5 |  1900/ 4431 batches | ms/batch 227.73 | loss  6.92
# | epoch   5 |  2000/ 4431 batches | ms/batch 222.18 | loss  6.39
# | epoch   5 |  2100/ 4431 batches | ms/batch 223.87 | loss  6.46
# | epoch   5 |  2200/ 4431 batches | ms/batch 222.04 | loss  6.81
# | epoch   5 |  2300/ 4431 batches | ms/batch 224.24 | loss  6.45
# | epoch   5 |  2400/ 4431 batches | ms/batch 224.14 | loss  6.75
# | epoch   5 |  2500/ 4431 batches | ms/batch 226.04 | loss  6.61
# | epoch   5 |  2600/ 4431 batches | ms/batch 224.15 | loss  6.04
# | epoch   5 |  2700/ 4431 batches | ms/batch 226.50 | loss  6.39
# | epoch   5 |  2800/ 4431 batches | ms/batch 221.38 | loss  6.51
# | epoch   5 |  2900/ 4431 batches | ms/batch 226.90 | loss  6.27
# | epoch   5 |  3000/ 4431 batches | ms/batch 228.34 | loss  6.56
# | epoch   5 |  3100/ 4431 batches | ms/batch 222.99 | loss  6.65
# | epoch   5 |  3200/ 4431 batches | ms/batch 226.97 | loss  6.42
# | epoch   5 |  3300/ 4431 batches | ms/batch 226.80 | loss  6.84
# | epoch   5 |  3400/ 4431 batches | ms/batch 223.77 | loss  6.88
# | epoch   5 |  3500/ 4431 batches | ms/batch 224.25 | loss  6.43
# | epoch   5 |  3600/ 4431 batches | ms/batch 226.68 | loss  6.63
# | epoch   5 |  3700/ 4431 batches | ms/batch 225.66 | loss  6.33
# | epoch   5 |  3800/ 4431 batches | ms/batch 225.63 | loss  6.50
# | epoch   5 |  3900/ 4431 batches | ms/batch 226.45 | loss  6.80
# | epoch   5 |  4000/ 4431 batches | ms/batch 224.92 | loss  6.65
# | epoch   5 |  4100/ 4431 batches | ms/batch 223.84 | loss  6.58
# | epoch   5 |  4200/ 4431 batches | ms/batch 223.32 | loss  6.85
# | epoch   5 |  4300/ 4431 batches | ms/batch 224.44 | loss  6.64
# | epoch   5 |  4400/ 4431 batches | ms/batch 220.46 | loss  6.25
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 993.83s
# -----------------------------------------------------------------------------------------
# | epoch   6 |   100/ 4431 batches | ms/batch 229.36 | loss  6.61
# | epoch   6 |   200/ 4431 batches | ms/batch 223.86 | loss  6.11
# | epoch   6 |   300/ 4431 batches | ms/batch 227.76 | loss  6.56
# | epoch   6 |   400/ 4431 batches | ms/batch 222.10 | loss  6.68
# | epoch   6 |   500/ 4431 batches | ms/batch 223.46 | loss  6.89
# | epoch   6 |   600/ 4431 batches | ms/batch 218.95 | loss  6.49
# | epoch   6 |   700/ 4431 batches | ms/batch 223.52 | loss  6.41
# | epoch   6 |   800/ 4431 batches | ms/batch 222.49 | loss  6.43
# | epoch   6 |   900/ 4431 batches | ms/batch 222.82 | loss  6.53
# | epoch   6 |  1000/ 4431 batches | ms/batch 224.03 | loss  6.54
# | epoch   6 |  1100/ 4431 batches | ms/batch 226.17 | loss  6.39
# | epoch   6 |  1200/ 4431 batches | ms/batch 221.16 | loss  6.32
# | epoch   6 |  1300/ 4431 batches | ms/batch 223.26 | loss  6.31
# | epoch   6 |  1400/ 4431 batches | ms/batch 226.51 | loss  6.78
# | epoch   6 |  1500/ 4431 batches | ms/batch 224.14 | loss  6.52
# | epoch   6 |  1600/ 4431 batches | ms/batch 228.78 | loss  6.13
# | epoch   6 |  1700/ 4431 batches | ms/batch 223.60 | loss  6.90
# | epoch   6 |  1800/ 4431 batches | ms/batch 229.95 | loss  6.18
# | epoch   6 |  1900/ 4431 batches | ms/batch 231.93 | loss  6.87
# | epoch   6 |  2000/ 4431 batches | ms/batch 238.99 | loss  6.29
# | epoch   6 |  2100/ 4431 batches | ms/batch 233.64 | loss  6.37
# | epoch   6 |  2200/ 4431 batches | ms/batch 219.25 | loss  6.71
# | epoch   6 |  2300/ 4431 batches | ms/batch 227.43 | loss  6.48
# | epoch   6 |  2400/ 4431 batches | ms/batch 224.53 | loss  6.68
# | epoch   6 |  2500/ 4431 batches | ms/batch 226.28 | loss  6.49
# | epoch   6 |  2600/ 4431 batches | ms/batch 227.16 | loss  5.95
# | epoch   6 |  2700/ 4431 batches | ms/batch 228.94 | loss  6.31
# | epoch   6 |  2800/ 4431 batches | ms/batch 230.11 | loss  6.42
# | epoch   6 |  2900/ 4431 batches | ms/batch 225.47 | loss  6.12
# | epoch   6 |  3000/ 4431 batches | ms/batch 226.02 | loss  6.50
# | epoch   6 |  3100/ 4431 batches | ms/batch 228.83 | loss  6.57
# | epoch   6 |  3200/ 4431 batches | ms/batch 228.53 | loss  6.34
# | epoch   6 |  3300/ 4431 batches | ms/batch 225.87 | loss  6.82
# | epoch   6 |  3400/ 4431 batches | ms/batch 227.60 | loss  6.83
# | epoch   6 |  3500/ 4431 batches | ms/batch 231.41 | loss  6.36
# | epoch   6 |  3600/ 4431 batches | ms/batch 229.30 | loss  6.52
# | epoch   6 |  3700/ 4431 batches | ms/batch 241.13 | loss  6.20
# | epoch   6 |  3800/ 4431 batches | ms/batch 225.23 | loss  6.44
# | epoch   6 |  3900/ 4431 batches | ms/batch 225.43 | loss  6.75
# | epoch   6 |  4000/ 4431 batches | ms/batch 224.02 | loss  6.52
# | epoch   6 |  4100/ 4431 batches | ms/batch 223.01 | loss  6.51
# | epoch   6 |  4200/ 4431 batches | ms/batch 226.13 | loss  6.73
# | epoch   6 |  4300/ 4431 batches | ms/batch 222.96 | loss  6.57
# | epoch   6 |  4400/ 4431 batches | ms/batch 225.54 | loss  6.13
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 1003.31s
# -----------------------------------------------------------------------------------------
# | epoch   7 |   100/ 4431 batches | ms/batch 225.97 | loss  6.52
# | epoch   7 |   200/ 4431 batches | ms/batch 219.16 | loss  6.06
# | epoch   7 |   300/ 4431 batches | ms/batch 225.21 | loss  6.43
# | epoch   7 |   400/ 4431 batches | ms/batch 223.80 | loss  6.60
# | epoch   7 |   500/ 4431 batches | ms/batch 225.40 | loss  6.78
# | epoch   7 |   600/ 4431 batches | ms/batch 222.08 | loss  6.35
# | epoch   7 |   700/ 4431 batches | ms/batch 226.60 | loss  6.30
# | epoch   7 |   800/ 4431 batches | ms/batch 223.16 | loss  6.29
# | epoch   7 |   900/ 4431 batches | ms/batch 224.36 | loss  6.46
# | epoch   7 |  1000/ 4431 batches | ms/batch 225.14 | loss  6.35
# | epoch   7 |  1100/ 4431 batches | ms/batch 229.23 | loss  6.21
# | epoch   7 |  1200/ 4431 batches | ms/batch 224.94 | loss  6.27
# | epoch   7 |  1300/ 4431 batches | ms/batch 225.20 | loss  6.18
# | epoch   7 |  1400/ 4431 batches | ms/batch 220.85 | loss  6.60
# | epoch   7 |  1500/ 4431 batches | ms/batch 224.72 | loss  6.39
# | epoch   7 |  1600/ 4431 batches | ms/batch 223.24 | loss  6.00
# | epoch   7 |  1700/ 4431 batches | ms/batch 224.29 | loss  6.73
# | epoch   7 |  1800/ 4431 batches | ms/batch 218.47 | loss  5.97
# | epoch   7 |  1900/ 4431 batches | ms/batch 223.61 | loss  6.81
# | epoch   7 |  2000/ 4431 batches | ms/batch 223.83 | loss  6.28
# | epoch   7 |  2100/ 4431 batches | ms/batch 222.79 | loss  6.32
# | epoch   7 |  2200/ 4431 batches | ms/batch 223.97 | loss  6.61
# | epoch   7 |  2300/ 4431 batches | ms/batch 226.39 | loss  6.25
# | epoch   7 |  2400/ 4431 batches | ms/batch 225.26 | loss  6.66
# | epoch   7 |  2500/ 4431 batches | ms/batch 224.50 | loss  6.41
# | epoch   7 |  2600/ 4431 batches | ms/batch 221.39 | loss  5.84
# | epoch   7 |  2700/ 4431 batches | ms/batch 228.62 | loss  6.17
# | epoch   7 |  2800/ 4431 batches | ms/batch 221.97 | loss  6.35
# | epoch   7 |  2900/ 4431 batches | ms/batch 227.87 | loss  6.02
# | epoch   7 |  3000/ 4431 batches | ms/batch 222.21 | loss  6.43
# | epoch   7 |  3100/ 4431 batches | ms/batch 220.27 | loss  6.43
# | epoch   7 |  3200/ 4431 batches | ms/batch 225.43 | loss  6.21
# | epoch   7 |  3300/ 4431 batches | ms/batch 225.58 | loss  6.69
# | epoch   7 |  3400/ 4431 batches | ms/batch 224.46 | loss  6.83
# | epoch   7 |  3500/ 4431 batches | ms/batch 221.90 | loss  6.30
# | epoch   7 |  3600/ 4431 batches | ms/batch 225.68 | loss  6.41
# | epoch   7 |  3700/ 4431 batches | ms/batch 225.83 | loss  6.16
# | epoch   7 |  3800/ 4431 batches | ms/batch 224.87 | loss  6.31
# | epoch   7 |  3900/ 4431 batches | ms/batch 220.06 | loss  6.78
# | epoch   7 |  4000/ 4431 batches | ms/batch 222.42 | loss  6.46
# | epoch   7 |  4100/ 4431 batches | ms/batch 223.21 | loss  6.45
# | epoch   7 |  4200/ 4431 batches | ms/batch 219.27 | loss  6.59
# | epoch   7 |  4300/ 4431 batches | ms/batch 224.38 | loss  6.49
# | epoch   7 |  4400/ 4431 batches | ms/batch 224.41 | loss  6.07
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 992.02s
# -----------------------------------------------------------------------------------------
# | epoch   8 |   100/ 4431 batches | ms/batch 219.92 | loss  6.48
# | epoch   8 |   200/ 4431 batches | ms/batch 223.16 | loss  6.03
# | epoch   8 |   300/ 4431 batches | ms/batch 222.78 | loss  6.39
# | epoch   8 |   400/ 4431 batches | ms/batch 224.23 | loss  6.56
# | epoch   8 |   500/ 4431 batches | ms/batch 222.07 | loss  6.71
# | epoch   8 |   600/ 4431 batches | ms/batch 220.89 | loss  6.30
# | epoch   8 |   700/ 4431 batches | ms/batch 221.76 | loss  6.23
# | epoch   8 |   800/ 4431 batches | ms/batch 223.87 | loss  6.24
# | epoch   8 |   900/ 4431 batches | ms/batch 224.38 | loss  6.39
# | epoch   8 |  1000/ 4431 batches | ms/batch 219.78 | loss  6.26
# | epoch   8 |  1100/ 4431 batches | ms/batch 220.80 | loss  6.10
# | epoch   8 |  1200/ 4431 batches | ms/batch 219.45 | loss  6.19
# | epoch   8 |  1300/ 4431 batches | ms/batch 226.47 | loss  6.15
# | epoch   8 |  1400/ 4431 batches | ms/batch 219.91 | loss  6.64
# | epoch   8 |  1500/ 4431 batches | ms/batch 220.45 | loss  6.27
# | epoch   8 |  1600/ 4431 batches | ms/batch 224.15 | loss  5.92
# | epoch   8 |  1700/ 4431 batches | ms/batch 222.18 | loss  6.69
# | epoch   8 |  1800/ 4431 batches | ms/batch 220.58 | loss  5.96
# | epoch   8 |  1900/ 4431 batches | ms/batch 224.32 | loss  6.74
# | epoch   8 |  2000/ 4431 batches | ms/batch 219.53 | loss  6.20
# | epoch   8 |  2100/ 4431 batches | ms/batch 220.56 | loss  6.22
# | epoch   8 |  2200/ 4431 batches | ms/batch 220.08 | loss  6.64
# | epoch   8 |  2300/ 4431 batches | ms/batch 219.95 | loss  6.19
# | epoch   8 |  2400/ 4431 batches | ms/batch 221.69 | loss  6.57
# | epoch   8 |  2500/ 4431 batches | ms/batch 222.61 | loss  6.38
# | epoch   8 |  2600/ 4431 batches | ms/batch 224.25 | loss  5.81
# | epoch   8 |  2700/ 4431 batches | ms/batch 223.14 | loss  6.09
# | epoch   8 |  2800/ 4431 batches | ms/batch 220.20 | loss  6.29
# | epoch   8 |  2900/ 4431 batches | ms/batch 221.88 | loss  5.94
# | epoch   8 |  3000/ 4431 batches | ms/batch 220.12 | loss  6.29
# | epoch   8 |  3100/ 4431 batches | ms/batch 217.92 | loss  6.38
# | epoch   8 |  3200/ 4431 batches | ms/batch 220.93 | loss  6.09
# | epoch   8 |  3300/ 4431 batches | ms/batch 220.57 | loss  6.65
# | epoch   8 |  3400/ 4431 batches | ms/batch 222.46 | loss  6.79
# | epoch   8 |  3500/ 4431 batches | ms/batch 224.40 | loss  6.21
# | epoch   8 |  3600/ 4431 batches | ms/batch 224.70 | loss  6.41
# | epoch   8 |  3700/ 4431 batches | ms/batch 223.74 | loss  6.04
# | epoch   8 |  3800/ 4431 batches | ms/batch 218.44 | loss  6.25
# | epoch   8 |  3900/ 4431 batches | ms/batch 220.01 | loss  6.68
# | epoch   8 |  4000/ 4431 batches | ms/batch 221.74 | loss  6.46
# | epoch   8 |  4100/ 4431 batches | ms/batch 220.72 | loss  6.40
# | epoch   8 |  4200/ 4431 batches | ms/batch 223.49 | loss  6.63
# | epoch   8 |  4300/ 4431 batches | ms/batch 218.38 | loss  6.48
# | epoch   8 |  4400/ 4431 batches | ms/batch 222.32 | loss  5.99
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 982.29s
# -----------------------------------------------------------------------------------------
# | epoch   9 |   100/ 4431 batches | ms/batch 225.28 | loss  6.37
# | epoch   9 |   200/ 4431 batches | ms/batch 221.64 | loss  5.95
# | epoch   9 |   300/ 4431 batches | ms/batch 224.09 | loss  6.33
# | epoch   9 |   400/ 4431 batches | ms/batch 221.47 | loss  6.58
# | epoch   9 |   500/ 4431 batches | ms/batch 221.55 | loss  6.65
# | epoch   9 |   600/ 4431 batches | ms/batch 218.91 | loss  6.22
# | epoch   9 |   700/ 4431 batches | ms/batch 219.44 | loss  6.20
# | epoch   9 |   800/ 4431 batches | ms/batch 222.77 | loss  6.16
# | epoch   9 |   900/ 4431 batches | ms/batch 220.98 | loss  6.41
# | epoch   9 |  1000/ 4431 batches | ms/batch 223.55 | loss  6.23
# | epoch   9 |  1100/ 4431 batches | ms/batch 225.47 | loss  6.12
# | epoch   9 |  1200/ 4431 batches | ms/batch 220.83 | loss  6.13
# | epoch   9 |  1300/ 4431 batches | ms/batch 224.17 | loss  6.08
# | epoch   9 |  1400/ 4431 batches | ms/batch 221.11 | loss  6.54
# | epoch   9 |  1500/ 4431 batches | ms/batch 223.16 | loss  6.27
# | epoch   9 |  1600/ 4431 batches | ms/batch 223.96 | loss  5.89
# | epoch   9 |  1700/ 4431 batches | ms/batch 221.68 | loss  6.75
# | epoch   9 |  1800/ 4431 batches | ms/batch 219.25 | loss  5.90
# | epoch   9 |  1900/ 4431 batches | ms/batch 222.21 | loss  6.67
# | epoch   9 |  2000/ 4431 batches | ms/batch 223.49 | loss  6.07
# | epoch   9 |  2100/ 4431 batches | ms/batch 223.70 | loss  6.20
# | epoch   9 |  2200/ 4431 batches | ms/batch 218.71 | loss  6.61
# | epoch   9 |  2300/ 4431 batches | ms/batch 223.17 | loss  6.11
# | epoch   9 |  2400/ 4431 batches | ms/batch 226.02 | loss  6.55
# | epoch   9 |  2500/ 4431 batches | ms/batch 217.55 | loss  6.34
# | epoch   9 |  2600/ 4431 batches | ms/batch 218.34 | loss  5.74
# | epoch   9 |  2700/ 4431 batches | ms/batch 221.89 | loss  6.06
# | epoch   9 |  2800/ 4431 batches | ms/batch 213.72 | loss  6.25
# | epoch   9 |  2900/ 4431 batches | ms/batch 221.26 | loss  5.91
# | epoch   9 |  3000/ 4431 batches | ms/batch 227.30 | loss  6.32
# | epoch   9 |  3100/ 4431 batches | ms/batch 222.85 | loss  6.37
# | epoch   9 |  3200/ 4431 batches | ms/batch 227.58 | loss  6.12
# | epoch   9 |  3300/ 4431 batches | ms/batch 219.32 | loss  6.58
# | epoch   9 |  3400/ 4431 batches | ms/batch 220.79 | loss  6.67
# | epoch   9 |  3500/ 4431 batches | ms/batch 220.15 | loss  6.25
# | epoch   9 |  3600/ 4431 batches | ms/batch 221.97 | loss  6.40
# | epoch   9 |  3700/ 4431 batches | ms/batch 216.37 | loss  5.94
# | epoch   9 |  3800/ 4431 batches | ms/batch 222.52 | loss  6.14
# | epoch   9 |  3900/ 4431 batches | ms/batch 223.61 | loss  6.65
# | epoch   9 |  4000/ 4431 batches | ms/batch 222.86 | loss  6.36
# | epoch   9 |  4100/ 4431 batches | ms/batch 222.38 | loss  6.30
# | epoch   9 |  4200/ 4431 batches | ms/batch 222.31 | loss  6.54
# | epoch   9 |  4300/ 4431 batches | ms/batch 224.83 | loss  6.38
# | epoch   9 |  4400/ 4431 batches | ms/batch 222.25 | loss  5.95
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 983.47s
# -----------------------------------------------------------------------------------------
# | epoch  10 |   100/ 4431 batches | ms/batch 225.07 | loss  6.35
# | epoch  10 |   200/ 4431 batches | ms/batch 222.88 | loss  5.88
# | epoch  10 |   300/ 4431 batches | ms/batch 221.44 | loss  6.32
# | epoch  10 |   400/ 4431 batches | ms/batch 221.20 | loss  6.52
# | epoch  10 |   500/ 4431 batches | ms/batch 221.26 | loss  6.66
# | epoch  10 |   600/ 4431 batches | ms/batch 224.47 | loss  6.18
# | epoch  10 |   700/ 4431 batches | ms/batch 231.13 | loss  6.15
# | epoch  10 |   800/ 4431 batches | ms/batch 233.73 | loss  6.16
# | epoch  10 |   900/ 4431 batches | ms/batch 222.00 | loss  6.33
# | epoch  10 |  1000/ 4431 batches | ms/batch 225.88 | loss  6.21
# | epoch  10 |  1100/ 4431 batches | ms/batch 232.07 | loss  6.05
# | epoch  10 |  1200/ 4431 batches | ms/batch 229.33 | loss  6.12
# | epoch  10 |  1300/ 4431 batches | ms/batch 224.42 | loss  6.05
# | epoch  10 |  1400/ 4431 batches | ms/batch 220.40 | loss  6.55
# | epoch  10 |  1500/ 4431 batches | ms/batch 220.83 | loss  6.21
# | epoch  10 |  1600/ 4431 batches | ms/batch 226.60 | loss  5.86
# | epoch  10 |  1700/ 4431 batches | ms/batch 220.81 | loss  6.63
# | epoch  10 |  1800/ 4431 batches | ms/batch 224.47 | loss  5.80
# | epoch  10 |  1900/ 4431 batches | ms/batch 219.81 | loss  6.69
# | epoch  10 |  2000/ 4431 batches | ms/batch 222.38 | loss  6.09
# | epoch  10 |  2100/ 4431 batches | ms/batch 218.90 | loss  6.19
# | epoch  10 |  2200/ 4431 batches | ms/batch 226.05 | loss  6.59
# | epoch  10 |  2300/ 4431 batches | ms/batch 219.66 | loss  6.05
# | epoch  10 |  2400/ 4431 batches | ms/batch 222.70 | loss  6.53
# | epoch  10 |  2500/ 4431 batches | ms/batch 220.26 | loss  6.26
# | epoch  10 |  2600/ 4431 batches | ms/batch 219.86 | loss  5.77
# | epoch  10 |  2700/ 4431 batches | ms/batch 219.52 | loss  6.03
# | epoch  10 |  2800/ 4431 batches | ms/batch 221.72 | loss  6.19
# | epoch  10 |  2900/ 4431 batches | ms/batch 217.54 | loss  5.91
# | epoch  10 |  3000/ 4431 batches | ms/batch 224.33 | loss  6.22
# | epoch  10 |  3100/ 4431 batches | ms/batch 223.26 | loss  6.30
# | epoch  10 |  3200/ 4431 batches | ms/batch 221.17 | loss  6.08
# | epoch  10 |  3300/ 4431 batches | ms/batch 219.96 | loss  6.56
# | epoch  10 |  3400/ 4431 batches | ms/batch 224.30 | loss  6.70
# | epoch  10 |  3500/ 4431 batches | ms/batch 225.73 | loss  6.14
# | epoch  10 |  3600/ 4431 batches | ms/batch 219.96 | loss  6.36
# | epoch  10 |  3700/ 4431 batches | ms/batch 221.37 | loss  5.96
# | epoch  10 |  3800/ 4431 batches | ms/batch 219.45 | loss  6.14
# | epoch  10 |  3900/ 4431 batches | ms/batch 224.78 | loss  6.63
# | epoch  10 |  4000/ 4431 batches | ms/batch 217.73 | loss  6.31
# | epoch  10 |  4100/ 4431 batches | ms/batch 217.12 | loss  6.29
# | epoch  10 |  4200/ 4431 batches | ms/batch 220.42 | loss  6.52
# | epoch  10 |  4300/ 4431 batches | ms/batch 219.85 | loss  6.36
# | epoch  10 |  4400/ 4431 batches | ms/batch 221.82 | loss  5.88
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 986.44s
# -----------------------------------------------------------------------------------------
# | epoch  11 |   100/ 4431 batches | ms/batch 219.35 | loss  6.34
# | epoch  11 |   200/ 4431 batches | ms/batch 225.07 | loss  5.91
# | epoch  11 |   300/ 4431 batches | ms/batch 222.19 | loss  6.30
# | epoch  11 |   400/ 4431 batches | ms/batch 219.77 | loss  6.53
# | epoch  11 |   500/ 4431 batches | ms/batch 221.80 | loss  6.62
# | epoch  11 |   600/ 4431 batches | ms/batch 218.06 | loss  6.21
# | epoch  11 |   700/ 4431 batches | ms/batch 220.87 | loss  6.13
# | epoch  11 |   800/ 4431 batches | ms/batch 218.20 | loss  6.11
# | epoch  11 |   900/ 4431 batches | ms/batch 222.32 | loss  6.30
# | epoch  11 |  1000/ 4431 batches | ms/batch 215.76 | loss  6.18
# | epoch  11 |  1100/ 4431 batches | ms/batch 221.65 | loss  6.01
# | epoch  11 |  1200/ 4431 batches | ms/batch 222.09 | loss  6.07
# | epoch  11 |  1300/ 4431 batches | ms/batch 215.22 | loss  5.97
# | epoch  11 |  1400/ 4431 batches | ms/batch 220.28 | loss  6.42
# | epoch  11 |  1500/ 4431 batches | ms/batch 222.14 | loss  6.15
# | epoch  11 |  1600/ 4431 batches | ms/batch 221.56 | loss  5.79
# | epoch  11 |  1700/ 4431 batches | ms/batch 222.05 | loss  6.62
# | epoch  11 |  1800/ 4431 batches | ms/batch 221.03 | loss  5.81
# | epoch  11 |  1900/ 4431 batches | ms/batch 220.18 | loss  6.60
# | epoch  11 |  2000/ 4431 batches | ms/batch 216.15 | loss  6.07
# | epoch  11 |  2100/ 4431 batches | ms/batch 222.24 | loss  6.17
# | epoch  11 |  2200/ 4431 batches | ms/batch 224.10 | loss  6.47
# | epoch  11 |  2300/ 4431 batches | ms/batch 222.37 | loss  6.05
# | epoch  11 |  2400/ 4431 batches | ms/batch 219.20 | loss  6.51
# | epoch  11 |  2500/ 4431 batches | ms/batch 220.05 | loss  6.28
# | epoch  11 |  2600/ 4431 batches | ms/batch 222.90 | loss  5.70
# | epoch  11 |  2700/ 4431 batches | ms/batch 220.27 | loss  6.01
# | epoch  11 |  2800/ 4431 batches | ms/batch 221.19 | loss  6.14
# | epoch  11 |  2900/ 4431 batches | ms/batch 219.72 | loss  5.81
# | epoch  11 |  3000/ 4431 batches | ms/batch 219.20 | loss  6.21
# | epoch  11 |  3100/ 4431 batches | ms/batch 216.93 | loss  6.26
# | epoch  11 |  3200/ 4431 batches | ms/batch 220.98 | loss  6.00
# | epoch  11 |  3300/ 4431 batches | ms/batch 218.10 | loss  6.46
# | epoch  11 |  3400/ 4431 batches | ms/batch 217.43 | loss  6.69
# | epoch  11 |  3500/ 4431 batches | ms/batch 222.63 | loss  6.11
# | epoch  11 |  3600/ 4431 batches | ms/batch 218.63 | loss  6.34
# | epoch  11 |  3700/ 4431 batches | ms/batch 222.49 | loss  6.01
# | epoch  11 |  3800/ 4431 batches | ms/batch 220.78 | loss  6.20
# | epoch  11 |  3900/ 4431 batches | ms/batch 223.55 | loss  6.65
# | epoch  11 |  4000/ 4431 batches | ms/batch 222.37 | loss  6.31
# | epoch  11 |  4100/ 4431 batches | ms/batch 224.25 | loss  6.27
# | epoch  11 |  4200/ 4431 batches | ms/batch 218.98 | loss  6.51
# | epoch  11 |  4300/ 4431 batches | ms/batch 220.16 | loss  6.29
# | epoch  11 |  4400/ 4431 batches | ms/batch 219.98 | loss  5.87
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 977.01s
# -----------------------------------------------------------------------------------------
# | epoch  12 |   100/ 4431 batches | ms/batch 226.03 | loss  6.28
# | epoch  12 |   200/ 4431 batches | ms/batch 222.21 | loss  5.77
# | epoch  12 |   300/ 4431 batches | ms/batch 222.54 | loss  6.25
# | epoch  12 |   400/ 4431 batches | ms/batch 219.76 | loss  6.46
# | epoch  12 |   500/ 4431 batches | ms/batch 217.07 | loss  6.68
# | epoch  12 |   600/ 4431 batches | ms/batch 216.97 | loss  6.12
# | epoch  12 |   700/ 4431 batches | ms/batch 218.70 | loss  6.11
# | epoch  12 |   800/ 4431 batches | ms/batch 221.63 | loss  6.12
# | epoch  12 |   900/ 4431 batches | ms/batch 219.90 | loss  6.36
# | epoch  12 |  1000/ 4431 batches | ms/batch 217.10 | loss  6.23
# | epoch  12 |  1100/ 4431 batches | ms/batch 223.83 | loss  6.05
# | epoch  12 |  1200/ 4431 batches | ms/batch 222.11 | loss  6.03
# | epoch  12 |  1300/ 4431 batches | ms/batch 219.90 | loss  6.07
# | epoch  12 |  1400/ 4431 batches | ms/batch 216.14 | loss  6.38
# | epoch  12 |  1500/ 4431 batches | ms/batch 223.41 | loss  6.17
# | epoch  12 |  1600/ 4431 batches | ms/batch 221.65 | loss  5.79
# | epoch  12 |  1700/ 4431 batches | ms/batch 216.58 | loss  6.59
# | epoch  12 |  1800/ 4431 batches | ms/batch 222.06 | loss  5.76
# | epoch  12 |  1900/ 4431 batches | ms/batch 224.36 | loss  6.63
# | epoch  12 |  2000/ 4431 batches | ms/batch 221.31 | loss  6.04
# | epoch  12 |  2100/ 4431 batches | ms/batch 218.14 | loss  6.08
# | epoch  12 |  2200/ 4431 batches | ms/batch 215.82 | loss  6.49
# | epoch  12 |  2300/ 4431 batches | ms/batch 222.03 | loss  6.08
# | epoch  12 |  2400/ 4431 batches | ms/batch 222.23 | loss  6.46
# | epoch  12 |  2500/ 4431 batches | ms/batch 223.03 | loss  6.24
# | epoch  12 |  2600/ 4431 batches | ms/batch 219.75 | loss  5.75
# | epoch  12 |  2700/ 4431 batches | ms/batch 218.52 | loss  6.00
# | epoch  12 |  2800/ 4431 batches | ms/batch 218.16 | loss  6.12
# | epoch  12 |  2900/ 4431 batches | ms/batch 222.40 | loss  5.77
# | epoch  12 |  3000/ 4431 batches | ms/batch 219.60 | loss  6.22
# | epoch  12 |  3100/ 4431 batches | ms/batch 217.02 | loss  6.28
# | epoch  12 |  3200/ 4431 batches | ms/batch 221.56 | loss  6.06
# | epoch  12 |  3300/ 4431 batches | ms/batch 220.67 | loss  6.51
# | epoch  12 |  3400/ 4431 batches | ms/batch 220.33 | loss  6.62
# | epoch  12 |  3500/ 4431 batches | ms/batch 223.67 | loss  6.15
# | epoch  12 |  3600/ 4431 batches | ms/batch 219.78 | loss  6.31
# | epoch  12 |  3700/ 4431 batches | ms/batch 221.25 | loss  5.91
# | epoch  12 |  3800/ 4431 batches | ms/batch 220.16 | loss  6.11
# | epoch  12 |  3900/ 4431 batches | ms/batch 218.34 | loss  6.58
# | epoch  12 |  4000/ 4431 batches | ms/batch 219.00 | loss  6.23
# | epoch  12 |  4100/ 4431 batches | ms/batch 218.21 | loss  6.30
# | epoch  12 |  4200/ 4431 batches | ms/batch 220.25 | loss  6.49
# | epoch  12 |  4300/ 4431 batches | ms/batch 221.19 | loss  6.30
# | epoch  12 |  4400/ 4431 batches | ms/batch 220.32 | loss  5.86
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 976.39s
# -----------------------------------------------------------------------------------------
# | epoch  13 |   100/ 4431 batches | ms/batch 218.17 | loss  6.30
# | epoch  13 |   200/ 4431 batches | ms/batch 219.60 | loss  5.79
# | epoch  13 |   300/ 4431 batches | ms/batch 218.79 | loss  6.19
# | epoch  13 |   400/ 4431 batches | ms/batch 219.64 | loss  6.51
# | epoch  13 |   500/ 4431 batches | ms/batch 218.66 | loss  6.59
# | epoch  13 |   600/ 4431 batches | ms/batch 223.32 | loss  6.08
# | epoch  13 |   700/ 4431 batches | ms/batch 217.18 | loss  6.07
# | epoch  13 |   800/ 4431 batches | ms/batch 215.43 | loss  6.00
# | epoch  13 |   900/ 4431 batches | ms/batch 219.51 | loss  6.27
# | epoch  13 |  1000/ 4431 batches | ms/batch 221.84 | loss  6.11
# | epoch  13 |  1100/ 4431 batches | ms/batch 223.19 | loss  6.01
# | epoch  13 |  1200/ 4431 batches | ms/batch 217.58 | loss  5.99
# | epoch  13 |  1300/ 4431 batches | ms/batch 220.90 | loss  6.04
# | epoch  13 |  1400/ 4431 batches | ms/batch 221.24 | loss  6.36
# | epoch  13 |  1500/ 4431 batches | ms/batch 223.38 | loss  6.18
# | epoch  13 |  1600/ 4431 batches | ms/batch 223.46 | loss  5.77
# | epoch  13 |  1700/ 4431 batches | ms/batch 218.62 | loss  6.52
# | epoch  13 |  1800/ 4431 batches | ms/batch 220.37 | loss  5.76
# | epoch  13 |  1900/ 4431 batches | ms/batch 219.63 | loss  6.59
# | epoch  13 |  2000/ 4431 batches | ms/batch 220.58 | loss  6.00
# | epoch  13 |  2100/ 4431 batches | ms/batch 220.88 | loss  6.14
# | epoch  13 |  2200/ 4431 batches | ms/batch 224.81 | loss  6.46
# | epoch  13 |  2300/ 4431 batches | ms/batch 219.13 | loss  6.06
# | epoch  13 |  2400/ 4431 batches | ms/batch 221.37 | loss  6.44
# | epoch  13 |  2500/ 4431 batches | ms/batch 219.85 | loss  6.23
# | epoch  13 |  2600/ 4431 batches | ms/batch 219.27 | loss  5.66
# | epoch  13 |  2700/ 4431 batches | ms/batch 214.82 | loss  5.95
# | epoch  13 |  2800/ 4431 batches | ms/batch 219.08 | loss  6.13
# | epoch  13 |  2900/ 4431 batches | ms/batch 222.30 | loss  5.83
# | epoch  13 |  3000/ 4431 batches | ms/batch 224.49 | loss  6.20
# | epoch  13 |  3100/ 4431 batches | ms/batch 220.57 | loss  6.17
# | epoch  13 |  3200/ 4431 batches | ms/batch 220.49 | loss  5.97
# | epoch  13 |  3300/ 4431 batches | ms/batch 221.19 | loss  6.43
# | epoch  13 |  3400/ 4431 batches | ms/batch 222.50 | loss  6.61
# | epoch  13 |  3500/ 4431 batches | ms/batch 217.74 | loss  6.10
# | epoch  13 |  3600/ 4431 batches | ms/batch 220.96 | loss  6.33
# | epoch  13 |  3700/ 4431 batches | ms/batch 219.13 | loss  5.93
# | epoch  13 |  3800/ 4431 batches | ms/batch 222.03 | loss  6.11
# | epoch  13 |  3900/ 4431 batches | ms/batch 219.27 | loss  6.57
# | epoch  13 |  4000/ 4431 batches | ms/batch 224.44 | loss  6.26
# | epoch  13 |  4100/ 4431 batches | ms/batch 221.10 | loss  6.24
# | epoch  13 |  4200/ 4431 batches | ms/batch 221.85 | loss  6.46
# | epoch  13 |  4300/ 4431 batches | ms/batch 221.84 | loss  6.25
# | epoch  13 |  4400/ 4431 batches | ms/batch 223.79 | loss  5.84
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 977.20s
# -----------------------------------------------------------------------------------------
# | epoch  14 |   100/ 4431 batches | ms/batch 223.35 | loss  6.26
# | epoch  14 |   200/ 4431 batches | ms/batch 214.62 | loss  5.71
# | epoch  14 |   300/ 4431 batches | ms/batch 221.50 | loss  6.22
# | epoch  14 |   400/ 4431 batches | ms/batch 223.79 | loss  6.45
# | epoch  14 |   500/ 4431 batches | ms/batch 221.42 | loss  6.56
# | epoch  14 |   600/ 4431 batches | ms/batch 215.17 | loss  6.11
# | epoch  14 |   700/ 4431 batches | ms/batch 224.23 | loss  6.07
# | epoch  14 |   800/ 4431 batches | ms/batch 222.79 | loss  5.99
# | epoch  14 |   900/ 4431 batches | ms/batch 220.67 | loss  6.27
# | epoch  14 |  1000/ 4431 batches | ms/batch 221.55 | loss  6.17
# | epoch  14 |  1100/ 4431 batches | ms/batch 221.41 | loss  6.04
# | epoch  14 |  1200/ 4431 batches | ms/batch 220.62 | loss  6.01
# | epoch  14 |  1300/ 4431 batches | ms/batch 218.73 | loss  5.99
# | epoch  14 |  1400/ 4431 batches | ms/batch 220.68 | loss  6.42
# | epoch  14 |  1500/ 4431 batches | ms/batch 224.10 | loss  6.16
# | epoch  14 |  1600/ 4431 batches | ms/batch 221.59 | loss  5.82
# | epoch  14 |  1700/ 4431 batches | ms/batch 222.38 | loss  6.50
# | epoch  14 |  1800/ 4431 batches | ms/batch 220.65 | loss  5.70
# | epoch  14 |  1900/ 4431 batches | ms/batch 223.51 | loss  6.57
# | epoch  14 |  2000/ 4431 batches | ms/batch 220.11 | loss  5.97
# | epoch  14 |  2100/ 4431 batches | ms/batch 219.59 | loss  6.10
# | epoch  14 |  2200/ 4431 batches | ms/batch 222.04 | loss  6.45
# | epoch  14 |  2300/ 4431 batches | ms/batch 223.82 | loss  6.01
# | epoch  14 |  2400/ 4431 batches | ms/batch 222.07 | loss  6.51
# | epoch  14 |  2500/ 4431 batches | ms/batch 222.94 | loss  6.25
# | epoch  14 |  2600/ 4431 batches | ms/batch 221.84 | loss  5.74
# | epoch  14 |  2700/ 4431 batches | ms/batch 221.47 | loss  5.97
# | epoch  14 |  2800/ 4431 batches | ms/batch 222.63 | loss  6.08
# | epoch  14 |  2900/ 4431 batches | ms/batch 221.43 | loss  5.82
# | epoch  14 |  3000/ 4431 batches | ms/batch 221.25 | loss  6.19
# | epoch  14 |  3100/ 4431 batches | ms/batch 220.71 | loss  6.24
# | epoch  14 |  3200/ 4431 batches | ms/batch 221.84 | loss  5.95
# | epoch  14 |  3300/ 4431 batches | ms/batch 220.22 | loss  6.43
# | epoch  14 |  3400/ 4431 batches | ms/batch 219.22 | loss  6.61
# | epoch  14 |  3500/ 4431 batches | ms/batch 221.52 | loss  6.12
# | epoch  14 |  3600/ 4431 batches | ms/batch 219.38 | loss  6.33
# | epoch  14 |  3700/ 4431 batches | ms/batch 219.12 | loss  5.93
# | epoch  14 |  3800/ 4431 batches | ms/batch 220.13 | loss  6.05
# | epoch  14 |  3900/ 4431 batches | ms/batch 222.86 | loss  6.54
# | epoch  14 |  4000/ 4431 batches | ms/batch 221.43 | loss  6.22
# | epoch  14 |  4100/ 4431 batches | ms/batch 220.33 | loss  6.18
# | epoch  14 |  4200/ 4431 batches | ms/batch 220.67 | loss  6.48
# | epoch  14 |  4300/ 4431 batches | ms/batch 224.68 | loss  6.26
# | epoch  14 |  4400/ 4431 batches | ms/batch 220.65 | loss  5.80
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 980.28s
# -----------------------------------------------------------------------------------------
# | epoch  15 |   100/ 4431 batches | ms/batch 223.36 | loss  6.29
# | epoch  15 |   200/ 4431 batches | ms/batch 224.06 | loss  5.76
# | epoch  15 |   300/ 4431 batches | ms/batch 220.97 | loss  6.18
# | epoch  15 |   400/ 4431 batches | ms/batch 219.72 | loss  6.43
# | epoch  15 |   500/ 4431 batches | ms/batch 221.04 | loss  6.57
# | epoch  15 |   600/ 4431 batches | ms/batch 221.30 | loss  6.07
# | epoch  15 |   700/ 4431 batches | ms/batch 220.68 | loss  6.07
# | epoch  15 |   800/ 4431 batches | ms/batch 218.57 | loss  5.97
# | epoch  15 |   900/ 4431 batches | ms/batch 215.92 | loss  6.28
# | epoch  15 |  1000/ 4431 batches | ms/batch 222.11 | loss  6.11
# | epoch  15 |  1100/ 4431 batches | ms/batch 222.85 | loss  5.99
# | epoch  15 |  1200/ 4431 batches | ms/batch 221.60 | loss  5.97
# | epoch  15 |  1300/ 4431 batches | ms/batch 221.25 | loss  5.96
# | epoch  15 |  1400/ 4431 batches | ms/batch 224.69 | loss  6.41
# | epoch  15 |  1500/ 4431 batches | ms/batch 217.94 | loss  6.15
# | epoch  15 |  1600/ 4431 batches | ms/batch 223.47 | loss  5.73
# | epoch  15 |  1700/ 4431 batches | ms/batch 221.31 | loss  6.47
# | epoch  15 |  1800/ 4431 batches | ms/batch 219.53 | loss  5.73
# | epoch  15 |  1900/ 4431 batches | ms/batch 220.59 | loss  6.58
# | epoch  15 |  2000/ 4431 batches | ms/batch 221.41 | loss  5.98
# | epoch  15 |  2100/ 4431 batches | ms/batch 221.04 | loss  6.13
# | epoch  15 |  2200/ 4431 batches | ms/batch 220.16 | loss  6.43
# | epoch  15 |  2300/ 4431 batches | ms/batch 221.14 | loss  5.96
# | epoch  15 |  2400/ 4431 batches | ms/batch 223.85 | loss  6.41
# | epoch  15 |  2500/ 4431 batches | ms/batch 218.98 | loss  6.18
# | epoch  15 |  2600/ 4431 batches | ms/batch 221.85 | loss  5.65
# | epoch  15 |  2700/ 4431 batches | ms/batch 218.92 | loss  5.94
# | epoch  15 |  2800/ 4431 batches | ms/batch 221.73 | loss  6.02
# | epoch  15 |  2900/ 4431 batches | ms/batch 223.80 | loss  5.72
# | epoch  15 |  3000/ 4431 batches | ms/batch 219.53 | loss  6.13
# | epoch  15 |  3100/ 4431 batches | ms/batch 221.52 | loss  6.20
# | epoch  15 |  3200/ 4431 batches | ms/batch 223.41 | loss  5.96
# | epoch  15 |  3300/ 4431 batches | ms/batch 219.88 | loss  6.47
# | epoch  15 |  3400/ 4431 batches | ms/batch 221.10 | loss  6.60
# | epoch  15 |  3500/ 4431 batches | ms/batch 219.73 | loss  6.08
# | epoch  15 |  3600/ 4431 batches | ms/batch 221.19 | loss  6.32
# | epoch  15 |  3700/ 4431 batches | ms/batch 219.79 | loss  5.83
# | epoch  15 |  3800/ 4431 batches | ms/batch 220.24 | loss  6.05
# | epoch  15 |  3900/ 4431 batches | ms/batch 218.59 | loss  6.57
# | epoch  15 |  4000/ 4431 batches | ms/batch 219.20 | loss  6.21
# | epoch  15 |  4100/ 4431 batches | ms/batch 218.71 | loss  6.20
# | epoch  15 |  4200/ 4431 batches | ms/batch 223.12 | loss  6.45
# | epoch  15 |  4300/ 4431 batches | ms/batch 220.43 | loss  6.24
# | epoch  15 |  4400/ 4431 batches | ms/batch 214.80 | loss  5.84
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 978.40s
# -----------------------------------------------------------------------------------------
# | epoch  16 |   100/ 4431 batches | ms/batch 225.64 | loss  6.25
# | epoch  16 |   200/ 4431 batches | ms/batch 222.22 | loss  5.77
# | epoch  16 |   300/ 4431 batches | ms/batch 221.06 | loss  6.13
# | epoch  16 |   400/ 4431 batches | ms/batch 219.03 | loss  6.43
# | epoch  16 |   500/ 4431 batches | ms/batch 220.90 | loss  6.57
# | epoch  16 |   600/ 4431 batches | ms/batch 223.03 | loss  6.08
# | epoch  16 |   700/ 4431 batches | ms/batch 222.05 | loss  6.05
# | epoch  16 |   800/ 4431 batches | ms/batch 219.83 | loss  5.95
# | epoch  16 |   900/ 4431 batches | ms/batch 224.16 | loss  6.23
# | epoch  16 |  1000/ 4431 batches | ms/batch 222.94 | loss  6.11
# | epoch  16 |  1100/ 4431 batches | ms/batch 221.14 | loss  5.95
# | epoch  16 |  1200/ 4431 batches | ms/batch 221.92 | loss  5.89
# | epoch  16 |  1300/ 4431 batches | ms/batch 220.92 | loss  5.98
# | epoch  16 |  1400/ 4431 batches | ms/batch 222.11 | loss  6.46
# ...
# | epoch  35 |  4300/ 4431 batches | ms/batch 224.18 | loss  6.08
# | epoch  35 |  4400/ 4431 batches | ms/batch 222.98 | loss  5.69
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 996.44s
# -----------------------------------------------------------------------------------------
# | epoch  36 |   100/ 4431 batches | ms/batch 228.57 | loss  6.11
# | epoch  36 |   200/ 4431 batches | ms/batch 226.82 | loss  5.62
# | epoch  36 |   300/ 4431 batches | ms/batch 218.24 | loss  6.00
# | epoch  36 |   400/ 4431 batches | ms/batch 222.49 | loss  6.39
# | epoch  36 |   500/ 4431 batches | ms/batch 226.27 | loss  6.47
# | epoch  36 |   600/ 4431 batches | ms/batch 227.01 | loss  5.93
# | epoch  36 |   700/ 4431 batches | ms/batch 223.79 | loss  5.97
# | epoch  36 |   800/ 4431 batches | ms/batch 227.85 | loss  5.86
# | epoch  36 |   900/ 4431 batches | ms/batch 224.92 | loss  6.19
# | epoch  36 |  1000/ 4431 batches | ms/batch 223.89 | loss  6.07
# | epoch  36 |  1100/ 4431 batches | ms/batch 221.14 | loss  5.88
# | epoch  36 |  1200/ 4431 batches | ms/batch 220.69 | loss  5.86
# | epoch  36 |  1300/ 4431 batches | ms/batch 222.29 | loss  5.83
# | epoch  36 |  1400/ 4431 batches | ms/batch 222.49 | loss  6.33
# | epoch  36 |  1500/ 4431 batches | ms/batch 224.00 | loss  6.09
# | epoch  36 |  1600/ 4431 batches | ms/batch 220.21 | loss  5.66
# | epoch  36 |  1700/ 4431 batches | ms/batch 224.15 | loss  6.46
# | epoch  36 |  1800/ 4431 batches | ms/batch 224.80 | loss  5.60
# | epoch  36 |  1900/ 4431 batches | ms/batch 226.61 | loss  6.47
# | epoch  36 |  2000/ 4431 batches | ms/batch 224.63 | loss  5.90
# | epoch  36 |  2100/ 4431 batches | ms/batch 223.06 | loss  6.01
# | epoch  36 |  2200/ 4431 batches | ms/batch 224.62 | loss  6.28
# | epoch  36 |  2300/ 4431 batches | ms/batch 221.30 | loss  5.89
# | epoch  36 |  2400/ 4431 batches | ms/batch 224.41 | loss  6.29
# | epoch  36 |  2500/ 4431 batches | ms/batch 225.70 | loss  6.11
# | epoch  36 |  2600/ 4431 batches | ms/batch 222.12 | loss  5.56
# | epoch  36 |  2700/ 4431 batches | ms/batch 226.52 | loss  5.82
# | epoch  36 |  2800/ 4431 batches | ms/batch 221.17 | loss  5.99
# | epoch  36 |  2900/ 4431 batches | ms/batch 225.18 | loss  5.66
# | epoch  36 |  3000/ 4431 batches | ms/batch 223.28 | loss  6.06
# | epoch  36 |  3100/ 4431 batches | ms/batch 222.58 | loss  6.07
# | epoch  36 |  3200/ 4431 batches | ms/batch 227.04 | loss  5.82
# | epoch  36 |  3300/ 4431 batches | ms/batch 221.47 | loss  6.30
# | epoch  36 |  3400/ 4431 batches | ms/batch 224.94 | loss  6.54
# | epoch  36 |  3500/ 4431 batches | ms/batch 221.62 | loss  6.06
# | epoch  36 |  3600/ 4431 batches | ms/batch 224.00 | loss  6.20
# | epoch  36 |  3700/ 4431 batches | ms/batch 221.83 | loss  5.81
# | epoch  36 |  3800/ 4431 batches | ms/batch 223.13 | loss  5.96
# | epoch  36 |  3900/ 4431 batches | ms/batch 223.36 | loss  6.44
# | epoch  36 |  4000/ 4431 batches | ms/batch 218.00 | loss  6.10
# | epoch  36 |  4100/ 4431 batches | ms/batch 223.33 | loss  6.09
# | epoch  36 |  4200/ 4431 batches | ms/batch 222.60 | loss  6.33
# | epoch  36 |  4300/ 4431 batches | ms/batch 222.46 | loss  6.12
# | epoch  36 |  4400/ 4431 batches | ms/batch 223.51 | loss  5.66
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 990.52s
# -----------------------------------------------------------------------------------------
# | epoch  37 |   100/ 4431 batches | ms/batch 221.84 | loss  6.16
# | epoch  37 |   200/ 4431 batches | ms/batch 221.34 | loss  5.64
# | epoch  37 |   300/ 4431 batches | ms/batch 221.87 | loss  6.08
# | epoch  37 |   400/ 4431 batches | ms/batch 223.51 | loss  6.32
# | epoch  37 |   500/ 4431 batches | ms/batch 225.25 | loss  6.46
# | epoch  37 |   600/ 4431 batches | ms/batch 223.56 | loss  5.92
# | epoch  37 |   700/ 4431 batches | ms/batch 223.20 | loss  5.97
# | epoch  37 |   800/ 4431 batches | ms/batch 222.64 | loss  5.90
# | epoch  37 |   900/ 4431 batches | ms/batch 222.44 | loss  6.16
# | epoch  37 |  1000/ 4431 batches | ms/batch 220.83 | loss  6.06
# | epoch  37 |  1100/ 4431 batches | ms/batch 222.82 | loss  5.84
# | epoch  37 |  1200/ 4431 batches | ms/batch 224.60 | loss  5.81
# | epoch  37 |  1300/ 4431 batches | ms/batch 218.14 | loss  5.85
# | epoch  37 |  1400/ 4431 batches | ms/batch 225.11 | loss  6.36
# | epoch  37 |  1500/ 4431 batches | ms/batch 224.95 | loss  6.03
# | epoch  37 |  1600/ 4431 batches | ms/batch 222.63 | loss  5.62
# | epoch  37 |  1700/ 4431 batches | ms/batch 219.35 | loss  6.43
# | epoch  37 |  1800/ 4431 batches | ms/batch 220.42 | loss  5.52
# | epoch  37 |  1900/ 4431 batches | ms/batch 225.54 | loss  6.44
# | epoch  37 |  2000/ 4431 batches | ms/batch 219.82 | loss  5.85
# | epoch  37 |  2100/ 4431 batches | ms/batch 219.55 | loss  5.97
# | epoch  37 |  2200/ 4431 batches | ms/batch 222.02 | loss  6.34
# | epoch  37 |  2300/ 4431 batches | ms/batch 221.07 | loss  5.88
# | epoch  37 |  2400/ 4431 batches | ms/batch 220.43 | loss  6.31
# | epoch  37 |  2500/ 4431 batches | ms/batch 224.38 | loss  6.10
# | epoch  37 |  2600/ 4431 batches | ms/batch 220.40 | loss  5.57
# | epoch  37 |  2700/ 4431 batches | ms/batch 222.93 | loss  5.86
# | epoch  37 |  2800/ 4431 batches | ms/batch 226.13 | loss  6.04
# | epoch  37 |  2900/ 4431 batches | ms/batch 225.69 | loss  5.60
# | epoch  37 |  3000/ 4431 batches | ms/batch 222.93 | loss  6.01
# | epoch  37 |  3100/ 4431 batches | ms/batch 224.67 | loss  6.05
# | epoch  37 |  3200/ 4431 batches | ms/batch 224.94 | loss  5.84
# | epoch  37 |  3300/ 4431 batches | ms/batch 233.24 | loss  6.33
# | epoch  37 |  3400/ 4431 batches | ms/batch 234.62 | loss  6.53
# | epoch  37 |  3500/ 4431 batches | ms/batch 231.29 | loss  5.99
# | epoch  37 |  3600/ 4431 batches | ms/batch 227.46 | loss  6.26
# | epoch  37 |  3700/ 4431 batches | ms/batch 222.34 | loss  5.79
# | epoch  37 |  3800/ 4431 batches | ms/batch 224.89 | loss  5.94
# | epoch  37 |  3900/ 4431 batches | ms/batch 226.82 | loss  6.47
# | epoch  37 |  4000/ 4431 batches | ms/batch 227.05 | loss  6.10
# | epoch  37 |  4100/ 4431 batches | ms/batch 227.12 | loss  6.09
# | epoch  37 |  4200/ 4431 batches | ms/batch 227.38 | loss  6.37
# | epoch  37 |  4300/ 4431 batches | ms/batch 222.72 | loss  6.09
# | epoch  37 |  4400/ 4431 batches | ms/batch 226.45 | loss  5.72
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 992.45s
# -----------------------------------------------------------------------------------------
# | epoch  38 |   100/ 4431 batches | ms/batch 219.42 | loss  6.13
# | epoch  38 |   200/ 4431 batches | ms/batch 222.29 | loss  5.65
# | epoch  38 |   300/ 4431 batches | ms/batch 227.31 | loss  6.03
# | epoch  38 |   400/ 4431 batches | ms/batch 230.68 | loss  6.36
# | epoch  38 |   500/ 4431 batches | ms/batch 221.30 | loss  6.47
# | epoch  38 |   600/ 4431 batches | ms/batch 223.82 | loss  5.93
# | epoch  38 |   700/ 4431 batches | ms/batch 227.24 | loss  5.96
# | epoch  38 |   800/ 4431 batches | ms/batch 224.58 | loss  5.94
# | epoch  38 |   900/ 4431 batches | ms/batch 225.17 | loss  6.14
# | epoch  38 |  1000/ 4431 batches | ms/batch 226.51 | loss  6.07
# | epoch  38 |  1100/ 4431 batches | ms/batch 226.40 | loss  5.86
# | epoch  38 |  1200/ 4431 batches | ms/batch 223.77 | loss  5.89
# | epoch  38 |  1300/ 4431 batches | ms/batch 226.03 | loss  5.82
# | epoch  38 |  1400/ 4431 batches | ms/batch 226.24 | loss  6.32
# | epoch  38 |  1500/ 4431 batches | ms/batch 223.46 | loss  6.00
# | epoch  38 |  1600/ 4431 batches | ms/batch 219.46 | loss  5.64
# | epoch  38 |  1700/ 4431 batches | ms/batch 225.91 | loss  6.46
# | epoch  38 |  1800/ 4431 batches | ms/batch 222.05 | loss  5.62
# | epoch  38 |  1900/ 4431 batches | ms/batch 223.52 | loss  6.41
# | epoch  38 |  2000/ 4431 batches | ms/batch 223.46 | loss  5.92
# | epoch  38 |  2100/ 4431 batches | ms/batch 226.31 | loss  5.92
# | epoch  38 |  2200/ 4431 batches | ms/batch 222.85 | loss  6.31
# | epoch  38 |  2300/ 4431 batches | ms/batch 224.67 | loss  5.87
# | epoch  38 |  2400/ 4431 batches | ms/batch 223.11 | loss  6.29
# | epoch  38 |  2500/ 4431 batches | ms/batch 227.85 | loss  6.07
# | epoch  38 |  2600/ 4431 batches | ms/batch 227.17 | loss  5.55
# | epoch  38 |  2700/ 4431 batches | ms/batch 225.39 | loss  5.85
# | epoch  38 |  2800/ 4431 batches | ms/batch 223.11 | loss  6.00
# | epoch  38 |  2900/ 4431 batches | ms/batch 223.06 | loss  5.61
# | epoch  38 |  3000/ 4431 batches | ms/batch 221.04 | loss  5.98
# | epoch  38 |  3100/ 4431 batches | ms/batch 219.40 | loss  6.04
# | epoch  38 |  3200/ 4431 batches | ms/batch 225.94 | loss  5.78
# | epoch  38 |  3300/ 4431 batches | ms/batch 220.13 | loss  6.36
# | epoch  38 |  3400/ 4431 batches | ms/batch 224.60 | loss  6.47
# | epoch  38 |  3500/ 4431 batches | ms/batch 223.41 | loss  6.02
# | epoch  38 |  3600/ 4431 batches | ms/batch 223.93 | loss  6.17
# | epoch  38 |  3700/ 4431 batches | ms/batch 224.39 | loss  5.74
# | epoch  38 |  3800/ 4431 batches | ms/batch 224.23 | loss  5.94
# | epoch  38 |  3900/ 4431 batches | ms/batch 225.12 | loss  6.46
# | epoch  38 |  4000/ 4431 batches | ms/batch 225.59 | loss  6.04
# | epoch  38 |  4100/ 4431 batches | ms/batch 222.23 | loss  6.08
# | epoch  38 |  4200/ 4431 batches | ms/batch 222.98 | loss  6.31
# | epoch  38 |  4300/ 4431 batches | ms/batch 221.69 | loss  6.12
# | epoch  38 |  4400/ 4431 batches | ms/batch 223.16 | loss  5.74
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 992.74s
# -----------------------------------------------------------------------------------------
# | epoch  39 |   100/ 4431 batches | ms/batch 223.18 | loss  6.12
# | epoch  39 |   200/ 4431 batches | ms/batch 225.08 | loss  5.62
# | epoch  39 |   300/ 4431 batches | ms/batch 221.47 | loss  6.03
# | epoch  39 |   400/ 4431 batches | ms/batch 221.31 | loss  6.39
# | epoch  39 |   500/ 4431 batches | ms/batch 224.05 | loss  6.46
# | epoch  39 |   600/ 4431 batches | ms/batch 223.64 | loss  5.89
# | epoch  39 |   700/ 4431 batches | ms/batch 219.23 | loss  5.96
# | epoch  39 |   800/ 4431 batches | ms/batch 219.37 | loss  5.89
# | epoch  39 |   900/ 4431 batches | ms/batch 223.00 | loss  6.16
# | epoch  39 |  1000/ 4431 batches | ms/batch 219.60 | loss  6.05
# | epoch  39 |  1100/ 4431 batches | ms/batch 224.69 | loss  5.87
# | epoch  39 |  1200/ 4431 batches | ms/batch 222.49 | loss  5.90
# | epoch  39 |  1300/ 4431 batches | ms/batch 224.00 | loss  5.85
# | epoch  39 |  1400/ 4431 batches | ms/batch 225.87 | loss  6.28
# | epoch  39 |  1500/ 4431 batches | ms/batch 219.21 | loss  5.97
# | epoch  39 |  1600/ 4431 batches | ms/batch 221.99 | loss  5.64
# | epoch  39 |  1700/ 4431 batches | ms/batch 218.52 | loss  6.42
# | epoch  39 |  1800/ 4431 batches | ms/batch 223.42 | loss  5.59
# | epoch  39 |  1900/ 4431 batches | ms/batch 220.74 | loss  6.40
# | epoch  39 |  2000/ 4431 batches | ms/batch 222.57 | loss  5.91
# | epoch  39 |  2100/ 4431 batches | ms/batch 221.01 | loss  5.94
# | epoch  39 |  2200/ 4431 batches | ms/batch 220.56 | loss  6.34
# | epoch  39 |  2300/ 4431 batches | ms/batch 221.60 | loss  5.87
# | epoch  39 |  2400/ 4431 batches | ms/batch 222.75 | loss  6.29
# | epoch  39 |  2500/ 4431 batches | ms/batch 225.83 | loss  6.05
# | epoch  39 |  2600/ 4431 batches | ms/batch 219.61 | loss  5.59
# | epoch  39 |  2700/ 4431 batches | ms/batch 222.17 | loss  5.85
# | epoch  39 |  2800/ 4431 batches | ms/batch 224.66 | loss  6.04
# | epoch  39 |  2900/ 4431 batches | ms/batch 221.41 | loss  5.58
# | epoch  39 |  3000/ 4431 batches | ms/batch 220.70 | loss  5.98
# | epoch  39 |  3100/ 4431 batches | ms/batch 222.14 | loss  6.10
# | epoch  39 |  3200/ 4431 batches | ms/batch 221.67 | loss  5.81
# | epoch  39 |  3300/ 4431 batches | ms/batch 222.25 | loss  6.33
# | epoch  39 |  3400/ 4431 batches | ms/batch 218.56 | loss  6.46
# | epoch  39 |  3500/ 4431 batches | ms/batch 224.49 | loss  6.03
# | epoch  39 |  3600/ 4431 batches | ms/batch 220.81 | loss  6.19
# | epoch  39 |  3700/ 4431 batches | ms/batch 220.98 | loss  5.75
# | epoch  39 |  3800/ 4431 batches | ms/batch 217.73 | loss  5.95
# | epoch  39 |  3900/ 4431 batches | ms/batch 219.08 | loss  6.46
# | epoch  39 |  4000/ 4431 batches | ms/batch 219.45 | loss  6.01
# | epoch  39 |  4100/ 4431 batches | ms/batch 219.77 | loss  6.07
# | epoch  39 |  4200/ 4431 batches | ms/batch 223.73 | loss  6.37
# | epoch  39 |  4300/ 4431 batches | ms/batch 221.91 | loss  6.08
# | epoch  39 |  4400/ 4431 batches | ms/batch 222.98 | loss  5.67
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 982.73s
# -----------------------------------------------------------------------------------------
# | epoch  40 |   100/ 4431 batches | ms/batch 223.00 | loss  6.15
# | epoch  40 |   200/ 4431 batches | ms/batch 222.37 | loss  5.59
# | epoch  40 |   300/ 4431 batches | ms/batch 222.10 | loss  6.00
# | epoch  40 |   400/ 4431 batches | ms/batch 223.80 | loss  6.37
# | epoch  40 |   500/ 4431 batches | ms/batch 222.49 | loss  6.49
# | epoch  40 |   600/ 4431 batches | ms/batch 221.15 | loss  5.94
# | epoch  40 |   700/ 4431 batches | ms/batch 221.87 | loss  5.98
# | epoch  40 |   800/ 4431 batches | ms/batch 221.12 | loss  5.89
# | epoch  40 |   900/ 4431 batches | ms/batch 221.12 | loss  6.16
# | epoch  40 |  1000/ 4431 batches | ms/batch 223.87 | loss  6.05
# | epoch  40 |  1100/ 4431 batches | ms/batch 220.10 | loss  5.86
# | epoch  40 |  1200/ 4431 batches | ms/batch 223.51 | loss  5.85
# | epoch  40 |  1300/ 4431 batches | ms/batch 224.05 | loss  5.91
# | epoch  40 |  1400/ 4431 batches | ms/batch 226.26 | loss  6.32
# | epoch  40 |  1500/ 4431 batches | ms/batch 218.60 | loss  6.02
# | epoch  40 |  1600/ 4431 batches | ms/batch 223.40 | loss  5.63
# | epoch  40 |  1700/ 4431 batches | ms/batch 223.79 | loss  6.41
# | epoch  40 |  1800/ 4431 batches | ms/batch 219.04 | loss  5.56
# | epoch  40 |  1900/ 4431 batches | ms/batch 220.72 | loss  6.43
# | epoch  40 |  2000/ 4431 batches | ms/batch 222.32 | loss  5.91
# | epoch  40 |  2100/ 4431 batches | ms/batch 240.48 | loss  6.00
# | epoch  40 |  2200/ 4431 batches | ms/batch 232.24 | loss  6.29
# | epoch  40 |  2300/ 4431 batches | ms/batch 224.16 | loss  5.89
# | epoch  40 |  2400/ 4431 batches | ms/batch 220.89 | loss  6.24
# | epoch  40 |  2500/ 4431 batches | ms/batch 224.50 | loss  6.04
# | epoch  40 |  2600/ 4431 batches | ms/batch 224.72 | loss  5.49
# | epoch  40 |  2700/ 4431 batches | ms/batch 216.47 | loss  5.85
# | epoch  40 |  2800/ 4431 batches | ms/batch 223.73 | loss  6.01
# | epoch  40 |  2900/ 4431 batches | ms/batch 222.12 | loss  5.61
# | epoch  40 |  3000/ 4431 batches | ms/batch 222.72 | loss  5.97
# | epoch  40 |  3100/ 4431 batches | ms/batch 217.15 | loss  6.11
# | epoch  40 |  3200/ 4431 batches | ms/batch 220.52 | loss  5.80
# | epoch  40 |  3300/ 4431 batches | ms/batch 222.00 | loss  6.33
# | epoch  40 |  3400/ 4431 batches | ms/batch 222.37 | loss  6.45
# | epoch  40 |  3500/ 4431 batches | ms/batch 220.46 | loss  6.01
# | epoch  40 |  3600/ 4431 batches | ms/batch 221.66 | loss  6.19
# | epoch  40 |  3700/ 4431 batches | ms/batch 221.51 | loss  5.77
# | epoch  40 |  3800/ 4431 batches | ms/batch 221.12 | loss  5.96
# | epoch  40 |  3900/ 4431 batches | ms/batch 220.07 | loss  6.44
# | epoch  40 |  4000/ 4431 batches | ms/batch 223.34 | loss  6.09
# | epoch  40 |  4100/ 4431 batches | ms/batch 224.01 | loss  6.05
# | epoch  40 |  4200/ 4431 batches | ms/batch 218.60 | loss  6.34
# | epoch  40 |  4300/ 4431 batches | ms/batch 219.21 | loss  6.13
# | epoch  40 |  4400/ 4431 batches | ms/batch 224.07 | loss  5.64
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 985.99s
# -----------------------------------------------------------------------------------------
