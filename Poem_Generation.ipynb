# %% [markdown]
# ## Model

# %%
import torch.nn as nn

# %%
class LSTMModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, ntoken, ninp, nhid, nlayers, dropout=0.5):
        super(LSTMModel, self).__init__()
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.rnn = nn.LSTM(ninp, nhid, nlayers, dropout=dropout)
        self.decoder = nn.Linear(nhid, ntoken)

        self.init_weights()

        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                weight.new_zeros(self.nlayers, bsz, self.nhid))

# %% [markdown]
# ## Data preprocessing

# %%
import os
from io import open
import torch
from nltk.tokenize import word_tokenize
import json

class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path):
        self.dictionary = Dictionary()
        self.train = self.tokenize(os.path.join(path, 'poems.json'))

    def tokenize(self, path):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding="utf8") as f:
            tokens = 0
            for poem in f:
                poem_json = json.loads(poem)
                lines = poem_json['text'].split('\n') + ['end_of_poem']
                for words in lines:
                    tokens += len(words)
                    for word in word_tokenize(words):
                        self.dictionary.add_word(word.lower())

        # Tokenize file content
        with open(path, 'r', encoding="utf8") as f:
            ids = torch.LongTensor(tokens)
            token = 0
            for poem in f:
                poem_json = json.loads(poem)
                lines = poem_json['text'].split('\n') + ['end_of_poem']
                for words in lines:
                    for word in word_tokenize(words):
                        ids[token] = self.dictionary.word2idx[word.lower()]
                        token += 1

        return ids

# %% [markdown]
# ## Build and train

# %%
import time
import math
import os
import torch
import torch.nn as nn

# %% [markdown]
# Set the hyperparameters

# %%
# parameters
seed = 1111
data = './'
batch_size = 20
emsize = 200
nhid = 200
nlayers = 2
dropout = 0.2
bptt = 35
log_interval = 100
lr = 20
epochs = 40
save = 'model.pt'
clip = 0.25

# Set the random seed manually for reproducibility.
torch.manual_seed(seed)

device = torch.device("cpu")

# %%
###############################################################################
# Load data
###############################################################################

corpus = Corpus(data)

# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

train_data = batchify(corpus.train, batch_size)

###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
model = LSTMModel(ntokens, emsize, nhid, nlayers, dropout).to(device)

criterion = nn.CrossEntropyLoss()

###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        # the idea is to backprop like SGD (bptt)
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        
        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        for p in model.parameters():
            p.data.add_(-lr, p.grad.data)

        total_loss += loss.item()

        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // bptt, lr,
                elapsed * 1000 / log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# %%
# Loop over epochs.
best_val_loss = None

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s '.format(epoch, (time.time() - epoch_start_time)))
        print('-' * 89)
        # Save the model
        with open(save, 'wb') as f:
            torch.save(model, f)
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# | epoch   1 |   100/ 6133 batches | lr 20.00 | ms/batch 1198.44 | loss  2.51 | ppl    12.26
# -----------------------------------------------------------------------------------------
# Exiting from training early

# %% [markdown]
# ## Generate poems

# %%
import string

###############################################################################
# Language Modeling
#
# This file generates new sentences sampled from the language model
#
###############################################################################

temperature = 1.0
checkpoint = './model.pt'
outf = 'generated.txt'
words = 200

# Set the random seed manually for reproducibility.
torch.manual_seed(0)

with open(checkpoint, 'rb') as f:
    model = torch.load(f).to(device)
model.eval()

corpus = Corpus(data)
ntokens = len(corpus.dictionary)

hidden = model.init_hidden(1)
input = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)

with open(outf, 'w') as outf:
    with torch.no_grad():  # no tracking history
        # write the initial inputs
        word_idx = input.item()
        word = corpus.dictionary.idx2word[word_idx]
        if word in string.punctuation:
            write_down = word + '\n'
        else:
            write_down = word + ' '
        outf.write(write_down)
        for i in range(words):
            output, hidden = model(input, hidden)
            # use softmax to calculate the output weights
            #word_weights = torch.nn.functional.softmax(output.squeeze(),0)
            word_weights = output.squeeze().exp().cpu()
            word_idx = torch.multinomial(word_weights, 1)[0]
            input.fill_(word_idx)
            word = corpus.dictionary.idx2word[word_idx]
            
            print('Generated {}/{} words'.format(i, words))
            
            if word == 'end_of_poem':
                break
            
            if word in string.punctuation:
                write_down = word + '\n'
            else:
                write_down = word + ' '
            outf.write(write_down)
# Out:
# Generated 0/200 words
# Generated 1/200 words
# Generated 2/200 words
# Generated 3/200 words
# Generated 4/200 words
# Generated 5/200 words
# Generated 6/200 words
# Generated 7/200 words
# Generated 8/200 words
# Generated 9/200 words
# Generated 10/200 words
# Generated 11/200 words
# Generated 12/200 words
# Generated 13/200 words
# Generated 14/200 words
# Generated 15/200 words
# Generated 16/200 words
# Generated 17/200 words
# Generated 18/200 words
# Generated 19/200 words
# Generated 20/200 words
# Generated 21/200 words
# Generated 22/200 words
# Generated 23/200 words
# Generated 24/200 words
# Generated 25/200 words
# Generated 26/200 words
# Generated 27/200 words
# Generated 28/200 words
# Generated 29/200 words
# Generated 30/200 words
# Generated 31/200 words
# Generated 32/200 words
# Generated 33/200 words
# Generated 34/200 words
# Generated 35/200 words
# Generated 36/200 words
# Generated 37/200 words
# Generated 38/200 words
# Generated 39/200 words
# Generated 40/200 words
# Generated 41/200 words
# Generated 42/200 words
# Generated 43/200 words
# Generated 44/200 words
# Generated 45/200 words
# Generated 46/200 words
# Generated 47/200 words
# Generated 48/200 words
# Generated 49/200 words
# Generated 50/200 words
# Generated 51/200 words
# Generated 52/200 words
# Generated 53/200 words
# Generated 54/200 words
# Generated 55/200 words
# Generated 56/200 words
# Generated 57/200 words
# Generated 58/200 words
# Generated 59/200 words
# Generated 60/200 words
# Generated 61/200 words
# Generated 62/200 words
# Generated 63/200 words
# Generated 64/200 words
# Generated 65/200 words
# Generated 66/200 words
# Generated 67/200 words
# Generated 68/200 words
# Generated 69/200 words
# Generated 70/200 words
# Generated 71/200 words
# Generated 72/200 words
# Generated 73/200 words
# Generated 74/200 words
# Generated 75/200 words
# Generated 76/200 words
# Generated 77/200 words
# Generated 78/200 words
# Generated 79/200 words
# Generated 80/200 words
# Generated 81/200 words
# Generated 82/200 words
# Generated 83/200 words
# Generated 84/200 words
# Generated 85/200 words
# Generated 86/200 words
# Generated 87/200 words
# Generated 88/200 words
# Generated 89/200 words
# Generated 90/200 words
# Generated 91/200 words
# Generated 92/200 words
# Generated 93/200 words
# Generated 94/200 words
# Generated 95/200 words
# Generated 96/200 words
# Generated 97/200 words
# Generated 98/200 words
# Generated 99/200 words
# Generated 100/200 words
# Generated 101/200 words
# Generated 102/200 words
# Generated 103/200 words
# Generated 104/200 words
# Generated 105/200 words
# Generated 106/200 words
# Generated 107/200 words
# Generated 108/200 words
# Generated 109/200 words
# Generated 110/200 words
# Generated 111/200 words
# Generated 112/200 words
# Generated 113/200 words
# Generated 114/200 words
# Generated 115/200 words
# Generated 116/200 words
# Generated 117/200 words
# Generated 118/200 words
# Generated 119/200 words
# Generated 120/200 words
# Generated 121/200 words
# Generated 122/200 words
# Generated 123/200 words
# Generated 124/200 words
# Generated 125/200 words
# Generated 126/200 words
# Generated 127/200 words
# Generated 128/200 words
# Generated 129/200 words
# Generated 130/200 words
# Generated 131/200 words
# Generated 132/200 words
# Generated 133/200 words
# Generated 134/200 words
# Generated 135/200 words
# Generated 136/200 words
# Generated 137/200 words
# Generated 138/200 words
# Generated 139/200 words
# Generated 140/200 words
# Generated 141/200 words
# Generated 142/200 words
# Generated 143/200 words
# Generated 144/200 words
# Generated 145/200 words
# Generated 146/200 words
# Generated 147/200 words
# Generated 148/200 words
# Generated 149/200 words
# Generated 150/200 words
# Generated 151/200 words
# Generated 152/200 words
# Generated 153/200 words
# Generated 154/200 words
# Generated 155/200 words
# Generated 156/200 words
# Generated 157/200 words
# Generated 158/200 words
# Generated 159/200 words
# Generated 160/200 words
# Generated 161/200 words
# Generated 162/200 words
# Generated 163/200 words
# Generated 164/200 words
# Generated 165/200 words
# Generated 166/200 words
# Generated 167/200 words
# Generated 168/200 words
# Generated 169/200 words
# Generated 170/200 words
# Generated 171/200 words
# Generated 172/200 words
# Generated 173/200 words
# Generated 174/200 words
# Generated 175/200 words
# Generated 176/200 words
# Generated 177/200 words
# Generated 178/200 words
# Generated 179/200 words
# Generated 180/200 words
# Generated 181/200 words
# Generated 182/200 words
# Generated 183/200 words
# Generated 184/200 words
# Generated 185/200 words
# Generated 186/200 words
# Generated 187/200 words
# Generated 188/200 words
# Generated 189/200 words
# Generated 190/200 words
# Generated 191/200 words
# Generated 192/200 words
# Generated 193/200 words
# Generated 194/200 words
# Generated 195/200 words
# Generated 196/200 words
# Generated 197/200 words
# Generated 198/200 words
# Generated 199/200 words

# %%
corpus.dictionary.word2idx[',']
# Out:
# 10
