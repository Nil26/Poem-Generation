# %% [markdown]
# ## Model

# %%
import torch.nn as nn

# %%
class LSTMModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, ntoken, ninp, nhid, nlayers, dropout=0.5):
        super(LSTMModel, self).__init__()
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.rnn = nn.LSTM(ninp, nhid, nlayers, dropout=dropout)
        self.decoder = nn.Linear(nhid, ntoken)

        self.init_weights()

        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                weight.new_zeros(self.nlayers, bsz, self.nhid))

# %% [markdown]
# ## Data preprocessing

# %%
import os
from io import open
import torch
from nltk.tokenize import wordpunct_tokenize
import json
import enchant
d_english = enchant.Dict("en_US")
valid_noword = ['end_of_poem','!','"',',','.',':',';','?']

class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path):
        self.dictionary = Dictionary()
        self.train = self.tokenize(os.path.join(path, 'poems.json'))

    def tokenize(self, path):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding="utf8") as f:
            tokens = 0
            for poem in f:
                poem_json = json.loads(poem)
                lines = poem_json['text'].split('\n') + ['end_of_poem']
                for words in lines:
                    for word in wordpunct_tokenize(words):
                        if d_english.check(word) or word in valid_noword:
                            self.dictionary.add_word(word.lower())
                            tokens += 1

        # Tokenize file content
        with open(path, 'r', encoding="utf8") as f:
            ids = torch.LongTensor(tokens)
            token = 0
            for poem in f:
                poem_json = json.loads(poem)
                lines = poem_json['text'].split('\n') + ['end_of_poem']
                for words in lines:
                    for word in wordpunct_tokenize(words):
                        if d_english.check(word) or word in valid_noword:
                            ids[token] = self.dictionary.word2idx[word.lower()]
                            token += 1

        return ids

# %% [markdown]
# ## Build and train

# %%
import time
import math
import os
import torch
import torch.nn as nn

# %% [markdown]
# Set the hyperparameters

# %%
# parameters
seed = 1111
data = './'
batch_size = 32
emsize = 200
nhid = 500
nlayers = 2
dropout = 0.5
bptt = 6
log_interval = 100
lr = 30
epochs = 40
save = 'model.pt'

# Set the random seed manually for reproducibility.
torch.manual_seed(seed)

device = torch.device("cpu")

# %%
###############################################################################
# Load data
###############################################################################

corpus = Corpus(data)

# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

train_data = batchify(corpus.train, batch_size)

###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
model = LSTMModel(ntokens, emsize, nhid, nlayers, dropout).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

def train():
    # Turn on training mode which enables dropout.
    model.train()
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        hidden = repackage_hidden(hidden)
        optimizer.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()                
        optimizer.step()
        # output to screen
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} '.format(
                epoch, batch, len(train_data) // bptt, lr,
                elapsed * 1000 / log_interval, loss.item()))
            start_time = time.time()

# %%
# Loop over epochs.
best_val_loss = None

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s '.format(epoch, (time.time() - epoch_start_time)))
        print('-' * 89)
        # Save the model
        with open(save, 'wb') as f:
            torch.save(model, f)
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# | epoch   1 |   100/ 4550 batches | lr 30.00 | ms/batch 435.33 | loss  9.91
# | epoch   1 |   200/ 4550 batches | lr 30.00 | ms/batch 440.69 | loss  8.08
# | epoch   1 |   300/ 4550 batches | lr 30.00 | ms/batch 413.98 | loss  7.78
# | epoch   1 |   400/ 4550 batches | lr 30.00 | ms/batch 420.85 | loss  7.56
# | epoch   1 |   500/ 4550 batches | lr 30.00 | ms/batch 428.54 | loss  7.46
# | epoch   1 |   600/ 4550 batches | lr 30.00 | ms/batch 411.12 | loss  7.48
# | epoch   1 |   700/ 4550 batches | lr 30.00 | ms/batch 394.20 | loss  6.98
# | epoch   1 |   800/ 4550 batches | lr 30.00 | ms/batch 387.46 | loss  7.13
# | epoch   1 |   900/ 4550 batches | lr 30.00 | ms/batch 390.85 | loss  6.93
# | epoch   1 |  1000/ 4550 batches | lr 30.00 | ms/batch 390.45 | loss  6.96
# | epoch   1 |  1100/ 4550 batches | lr 30.00 | ms/batch 390.93 | loss  6.91
# | epoch   1 |  1200/ 4550 batches | lr 30.00 | ms/batch 390.63 | loss  6.91
# | epoch   1 |  1300/ 4550 batches | lr 30.00 | ms/batch 390.92 | loss  7.30
# | epoch   1 |  1400/ 4550 batches | lr 30.00 | ms/batch 390.12 | loss  6.94
# | epoch   1 |  1500/ 4550 batches | lr 30.00 | ms/batch 389.84 | loss  6.94
# | epoch   1 |  1600/ 4550 batches | lr 30.00 | ms/batch 392.24 | loss  6.89
# | epoch   1 |  1700/ 4550 batches | lr 30.00 | ms/batch 393.45 | loss  7.05
# | epoch   1 |  1800/ 4550 batches | lr 30.00 | ms/batch 396.59 | loss  7.32
# | epoch   1 |  1900/ 4550 batches | lr 30.00 | ms/batch 395.80 | loss  7.01
# | epoch   1 |  2000/ 4550 batches | lr 30.00 | ms/batch 394.44 | loss  7.17
# | epoch   1 |  2100/ 4550 batches | lr 30.00 | ms/batch 395.61 | loss  6.88
# | epoch   1 |  2200/ 4550 batches | lr 30.00 | ms/batch 396.91 | loss  7.14
# | epoch   1 |  2300/ 4550 batches | lr 30.00 | ms/batch 402.54 | loss  6.92
# | epoch   1 |  2400/ 4550 batches | lr 30.00 | ms/batch 390.73 | loss  6.88
# | epoch   1 |  2500/ 4550 batches | lr 30.00 | ms/batch 392.30 | loss  6.49
# | epoch   1 |  2600/ 4550 batches | lr 30.00 | ms/batch 396.91 | loss  6.87
# | epoch   1 |  2700/ 4550 batches | lr 30.00 | ms/batch 400.37 | loss  6.99
# | epoch   1 |  2800/ 4550 batches | lr 30.00 | ms/batch 399.81 | loss  6.78
# | epoch   1 |  2900/ 4550 batches | lr 30.00 | ms/batch 395.85 | loss  6.85
# | epoch   1 |  3000/ 4550 batches | lr 30.00 | ms/batch 393.43 | loss  6.90
# | epoch   1 |  3100/ 4550 batches | lr 30.00 | ms/batch 390.43 | loss  6.96
# | epoch   1 |  3200/ 4550 batches | lr 30.00 | ms/batch 391.93 | loss  7.04
# | epoch   1 |  3300/ 4550 batches | lr 30.00 | ms/batch 395.25 | loss  7.34
# | epoch   1 |  3400/ 4550 batches | lr 30.00 | ms/batch 396.05 | loss  6.97
# | epoch   1 |  3500/ 4550 batches | lr 30.00 | ms/batch 390.32 | loss  6.70
# | epoch   1 |  3600/ 4550 batches | lr 30.00 | ms/batch 395.34 | loss  7.01
# | epoch   1 |  3700/ 4550 batches | lr 30.00 | ms/batch 389.28 | loss  6.73
# | epoch   1 |  3800/ 4550 batches | lr 30.00 | ms/batch 390.66 | loss  7.29
# | epoch   1 |  3900/ 4550 batches | lr 30.00 | ms/batch 390.30 | loss  6.84
# | epoch   1 |  4000/ 4550 batches | lr 30.00 | ms/batch 390.80 | loss  6.94
# | epoch   1 |  4100/ 4550 batches | lr 30.00 | ms/batch 390.63 | loss  6.81
# | epoch   1 |  4200/ 4550 batches | lr 30.00 | ms/batch 398.14 | loss  6.80
# | epoch   1 |  4300/ 4550 batches | lr 30.00 | ms/batch 390.41 | loss  7.26
# | epoch   1 |  4400/ 4550 batches | lr 30.00 | ms/batch 388.64 | loss  6.99
# | epoch   1 |  4500/ 4550 batches | lr 30.00 | ms/batch 386.24 | loss  6.74
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 1806.85s
# -----------------------------------------------------------------------------------------
# /Users/zhshang/anaconda3/lib/python3.7/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type LSTMModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# | epoch   2 |   100/ 4550 batches | lr 30.00 | ms/batch 393.83 | loss  6.69
# | epoch   2 |   200/ 4550 batches | lr 30.00 | ms/batch 387.86 | loss  6.86
# | epoch   2 |   300/ 4550 batches | lr 30.00 | ms/batch 387.70 | loss  6.92
# | epoch   2 |   400/ 4550 batches | lr 30.00 | ms/batch 388.09 | loss  6.91
# | epoch   2 |   500/ 4550 batches | lr 30.00 | ms/batch 387.72 | loss  7.02
# | epoch   2 |   600/ 4550 batches | lr 30.00 | ms/batch 386.88 | loss  6.96
# | epoch   2 |   700/ 4550 batches | lr 30.00 | ms/batch 387.04 | loss  6.72
# | epoch   2 |   800/ 4550 batches | lr 30.00 | ms/batch 384.91 | loss  6.94
# | epoch   2 |   900/ 4550 batches | lr 30.00 | ms/batch 387.31 | loss  6.66
# | epoch   2 |  1000/ 4550 batches | lr 30.00 | ms/batch 389.24 | loss  6.63
# | epoch   2 |  1100/ 4550 batches | lr 30.00 | ms/batch 389.57 | loss  6.61
# | epoch   2 |  1200/ 4550 batches | lr 30.00 | ms/batch 392.23 | loss  6.72
# | epoch   2 |  1300/ 4550 batches | lr 30.00 | ms/batch 394.38 | loss  7.09
# | epoch   2 |  1400/ 4550 batches | lr 30.00 | ms/batch 395.81 | loss  6.76
# | epoch   2 |  1500/ 4550 batches | lr 30.00 | ms/batch 393.76 | loss  6.78
# | epoch   2 |  1600/ 4550 batches | lr 30.00 | ms/batch 391.73 | loss  6.70
# | epoch   2 |  1700/ 4550 batches | lr 30.00 | ms/batch 388.47 | loss  6.85
# | epoch   2 |  1800/ 4550 batches | lr 30.00 | ms/batch 395.91 | loss  7.18
# | epoch   2 |  1900/ 4550 batches | lr 30.00 | ms/batch 393.01 | loss  6.86
# | epoch   2 |  2000/ 4550 batches | lr 30.00 | ms/batch 390.48 | loss  7.02
# | epoch   2 |  2100/ 4550 batches | lr 30.00 | ms/batch 389.51 | loss  6.79
# | epoch   2 |  2200/ 4550 batches | lr 30.00 | ms/batch 403.15 | loss  7.05
# | epoch   2 |  2300/ 4550 batches | lr 30.00 | ms/batch 389.04 | loss  6.82
# | epoch   2 |  2400/ 4550 batches | lr 30.00 | ms/batch 387.80 | loss  6.86
# | epoch   2 |  2500/ 4550 batches | lr 30.00 | ms/batch 386.99 | loss  6.40
# | epoch   2 |  2600/ 4550 batches | lr 30.00 | ms/batch 388.17 | loss  6.74
# | epoch   2 |  2700/ 4550 batches | lr 30.00 | ms/batch 388.56 | loss  6.89
# | epoch   2 |  2800/ 4550 batches | lr 30.00 | ms/batch 387.23 | loss  6.61
# | epoch   2 |  2900/ 4550 batches | lr 30.00 | ms/batch 386.35 | loss  6.71
# | epoch   2 |  3000/ 4550 batches | lr 30.00 | ms/batch 385.61 | loss  6.88
# | epoch   2 |  3100/ 4550 batches | lr 30.00 | ms/batch 387.23 | loss  6.84
# | epoch   2 |  3200/ 4550 batches | lr 30.00 | ms/batch 389.95 | loss  6.99
# | epoch   2 |  3300/ 4550 batches | lr 30.00 | ms/batch 391.63 | loss  7.27
# | epoch   2 |  3400/ 4550 batches | lr 30.00 | ms/batch 391.18 | loss  6.86
# | epoch   2 |  3500/ 4550 batches | lr 30.00 | ms/batch 387.54 | loss  6.67
# | epoch   2 |  3600/ 4550 batches | lr 30.00 | ms/batch 387.92 | loss  6.98
# | epoch   2 |  3700/ 4550 batches | lr 30.00 | ms/batch 388.90 | loss  6.70
# | epoch   2 |  3800/ 4550 batches | lr 30.00 | ms/batch 392.29 | loss  7.23
# | epoch   2 |  3900/ 4550 batches | lr 30.00 | ms/batch 396.04 | loss  6.78
# | epoch   2 |  4000/ 4550 batches | lr 30.00 | ms/batch 394.62 | loss  6.85
# | epoch   2 |  4100/ 4550 batches | lr 30.00 | ms/batch 388.93 | loss  6.75
# | epoch   2 |  4200/ 4550 batches | lr 30.00 | ms/batch 388.53 | loss  6.72
# | epoch   2 |  4300/ 4550 batches | lr 30.00 | ms/batch 396.91 | loss  7.16
# | epoch   2 |  4400/ 4550 batches | lr 30.00 | ms/batch 386.78 | loss  6.90
# | epoch   2 |  4500/ 4550 batches | lr 30.00 | ms/batch 386.97 | loss  6.66
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 1774.51s
# -----------------------------------------------------------------------------------------
# | epoch   3 |   100/ 4550 batches | lr 30.00 | ms/batch 389.03 | loss  6.61
# | epoch   3 |   200/ 4550 batches | lr 30.00 | ms/batch 386.53 | loss  6.81
# | epoch   3 |   300/ 4550 batches | lr 30.00 | ms/batch 389.08 | loss  6.93
# | epoch   3 |   400/ 4550 batches | lr 30.00 | ms/batch 393.14 | loss  6.88
# | epoch   3 |   500/ 4550 batches | lr 30.00 | ms/batch 396.30 | loss  6.94
# | epoch   3 |   600/ 4550 batches | lr 30.00 | ms/batch 385.81 | loss  6.88
# | epoch   3 |   700/ 4550 batches | lr 30.00 | ms/batch 392.02 | loss  6.63
# | epoch   3 |   800/ 4550 batches | lr 30.00 | ms/batch 388.42 | loss  6.86
# -----------------------------------------------------------------------------------------
# Exiting from training early

# %% [markdown]
# ## Generate poems

# %%
import string

###############################################################################
# Language Modeling
#
# This file generates new sentences sampled from the language model
#
###############################################################################

checkpoint = './model.pt'
outf = 'generated.txt'
words = 500

# Set the random seed manually for reproducibility.
torch.manual_seed(0)

with open(checkpoint, 'rb') as f:
    model = torch.load(f).to(device)
model.eval()

corpus = Corpus(data)
ntokens = len(corpus.dictionary)

hidden = model.init_hidden(1)
input = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)

with open(outf, 'w') as outf:
    with torch.no_grad():  # no tracking history
        # write the initial inputs
        word_idx = input.item()
        word = corpus.dictionary.idx2word[word_idx]
        if word in string.punctuation:
            write_down = word + '\n'
        else:
            write_down = word + ' '
        outf.write(write_down)
        for i in range(words):
            output, hidden = model(input, hidden)
            # use softmax to calculate the output weights
            word_weights = torch.nn.functional.softmax(output.squeeze(),0)
            word_idx = torch.multinomial(word_weights, 1)[0]
            input.fill_(word_idx)
            word = corpus.dictionary.idx2word[word_idx]
            
            print('Generated {}/{} words'.format(i, words))
            
            if word == 'end_of_poem':
                break
            
            if word in string.punctuation:
                write_down = word + '\n'
            else:
                write_down = word + ' '
            outf.write(write_down)
# Out:
# Generated 0/500 words
# Generated 1/500 words
# Generated 2/500 words
# Generated 3/500 words
# Generated 4/500 words
# Generated 5/500 words
# Generated 6/500 words
# Generated 7/500 words
# Generated 8/500 words
# Generated 9/500 words
# Generated 10/500 words
# Generated 11/500 words
# Generated 12/500 words
# Generated 13/500 words
# Generated 14/500 words
# Generated 15/500 words
# Generated 16/500 words
# Generated 17/500 words
# Generated 18/500 words
# Generated 19/500 words
# Generated 20/500 words
# Generated 21/500 words
# Generated 22/500 words
# Generated 23/500 words
# Generated 24/500 words
# Generated 25/500 words
# Generated 26/500 words
# Generated 27/500 words
# Generated 28/500 words
# Generated 29/500 words
# Generated 30/500 words
# Generated 31/500 words
# Generated 32/500 words
# Generated 33/500 words
# Generated 34/500 words
# Generated 35/500 words
# Generated 36/500 words
# Generated 37/500 words
# Generated 38/500 words
# Generated 39/500 words
# Generated 40/500 words
# Generated 41/500 words
# Generated 42/500 words
# Generated 43/500 words
# Generated 44/500 words
# Generated 45/500 words
# Generated 46/500 words
# Generated 47/500 words
# Generated 48/500 words
# Generated 49/500 words
# Generated 50/500 words
# Generated 51/500 words
# Generated 52/500 words
# Generated 53/500 words
# Generated 54/500 words
# Generated 55/500 words
# Generated 56/500 words
# Generated 57/500 words
# Generated 58/500 words
# Generated 59/500 words
# Generated 60/500 words
# Generated 61/500 words
# Generated 62/500 words
# Generated 63/500 words
# Generated 64/500 words
# Generated 65/500 words
# Generated 66/500 words
# Generated 67/500 words
# Generated 68/500 words
# Generated 69/500 words
# Generated 70/500 words
# Generated 71/500 words
# Generated 72/500 words
# Generated 73/500 words
# Generated 74/500 words
# Generated 75/500 words
# Generated 76/500 words
# Generated 77/500 words
# Generated 78/500 words
# Generated 79/500 words
# Generated 80/500 words
# Generated 81/500 words
# Generated 82/500 words
# Generated 83/500 words
# Generated 84/500 words
# Generated 85/500 words
# Generated 86/500 words
# Generated 87/500 words
# Generated 88/500 words
# Generated 89/500 words
# Generated 90/500 words
# Generated 91/500 words
# Generated 92/500 words
# Generated 93/500 words
# Generated 94/500 words
# Generated 95/500 words
# Generated 96/500 words
# Generated 97/500 words
# Generated 98/500 words
# Generated 99/500 words
# Generated 100/500 words
# Generated 101/500 words
# Generated 102/500 words
# Generated 103/500 words
# Generated 104/500 words
# Generated 105/500 words
# Generated 106/500 words
# Generated 107/500 words
# Generated 108/500 words
# Generated 109/500 words
# Generated 110/500 words
# Generated 111/500 words
# Generated 112/500 words
# Generated 113/500 words
# Generated 114/500 words
# Generated 115/500 words
# Generated 116/500 words
# Generated 117/500 words
# Generated 118/500 words
# Generated 119/500 words
# Generated 120/500 words
# Generated 121/500 words
# Generated 122/500 words
# Generated 123/500 words
# Generated 124/500 words
# Generated 125/500 words
# Generated 126/500 words
# Generated 127/500 words
# Generated 128/500 words
# Generated 129/500 words
# Generated 130/500 words
# Generated 131/500 words
# Generated 132/500 words
# Generated 133/500 words
# Generated 134/500 words
# Generated 135/500 words
# Generated 136/500 words
# Generated 137/500 words
# Generated 138/500 words
# Generated 139/500 words
# Generated 140/500 words
# Generated 141/500 words
# Generated 142/500 words
# Generated 143/500 words
# Generated 144/500 words
# Generated 145/500 words
# Generated 146/500 words
# Generated 147/500 words
# Generated 148/500 words
# Generated 149/500 words
# Generated 150/500 words
# Generated 151/500 words
# Generated 152/500 words
# Generated 153/500 words
# Generated 154/500 words
# Generated 155/500 words
# Generated 156/500 words
# Generated 157/500 words
# Generated 158/500 words
# Generated 159/500 words
# Generated 160/500 words
# Generated 161/500 words
# Generated 162/500 words
# Generated 163/500 words
# Generated 164/500 words
# Generated 165/500 words
# Generated 166/500 words
# Generated 167/500 words
# Generated 168/500 words
# Generated 169/500 words
# Generated 170/500 words
# Generated 171/500 words
# Generated 172/500 words
# Generated 173/500 words
# Generated 174/500 words
# Generated 175/500 words
# Generated 176/500 words
# Generated 177/500 words
# Generated 178/500 words
# Generated 179/500 words
# Generated 180/500 words
# Generated 181/500 words
# Generated 182/500 words
# Generated 183/500 words
# Generated 184/500 words
# Generated 185/500 words
# Generated 186/500 words
# Generated 187/500 words
# Generated 188/500 words
# Generated 189/500 words
# Generated 190/500 words
# Generated 191/500 words
# Generated 192/500 words
# Generated 193/500 words
# Generated 194/500 words
# Generated 195/500 words
# Generated 196/500 words
# Generated 197/500 words
# Generated 198/500 words
# Generated 199/500 words
# Generated 200/500 words
# Generated 201/500 words
# Generated 202/500 words
# Generated 203/500 words
# Generated 204/500 words
# Generated 205/500 words
# Generated 206/500 words
# Generated 207/500 words
# Generated 208/500 words
# Generated 209/500 words
# Generated 210/500 words
# Generated 211/500 words
# Generated 212/500 words
# Generated 213/500 words
# Generated 214/500 words
# Generated 215/500 words
# Generated 216/500 words
# Generated 217/500 words
# Generated 218/500 words
# Generated 219/500 words
# Generated 220/500 words
# Generated 221/500 words
# Generated 222/500 words
# Generated 223/500 words
# Generated 224/500 words
